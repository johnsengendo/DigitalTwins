# %%
"""
This code builds a LSTM model to predict the data transferred 1 second in the future, using data captured as bandwidth is increased.
1. Data Preparation: The dataset containing historical throughput and transferred data is prepared.

2. LSTM Model: A Long Short-Term Memory (LSTM) model is constructed to learn the patterns and trends in the throughput and transferred data.
   The model is trained on the historical data to predict future bandwidth values.

3. PID Integration: After training the LSTM model, a Proportional-Integral-Derivative (PID) controller is integrated into the prediction pipeline.
   The PID controller fine-tunes the predictions produced by the LSTM model to match the actual data transferred.

4. Demonstration: The combined LSTM-PID model is evaluated by comparing its predictions with the actual data transferred.
   This demonstrates how incorporating a PID controller can improve the accuracy of the LSTM model's predictions and better match the actual outputs.
"""
# Out:
# "\nThis code builds a LSTM model to predict the data transferred 2 seconds in the future, using data captured as bandwidth is increased.\n\n1. Data Preparation: The dataset containing historical throughput and transferred data is prepared.\n\n2. LSTM Model: A Long Short-Term Memory (LSTM) model is constructed to learn the patterns and trends in the throughput and transferred data.\n   The model is trained on the historical data to predict future bandwidth values.\n\n3. PID Integration: After training the LSTM model, a Proportional-Integral-Derivative (PID) controller is integrated into the prediction pipeline.\n   The PID controller fine-tunes the predictions produced by the LSTM model to match the actual data transferred.\n\n4. Demonstration: The combined LSTM-PID model is evaluated by comparing its predictions with the actual data transferred.\n   This demonstrates how incorporating a PID controller can improve the accuracy of the LSTM model's predictions and better match the actual outputs.\n"

# %%
# Importing necessary libraries
import os
import math
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,GRU, Dropout, Lambda, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta, Nadam
from keras import regularizers, backend as K, utils
from keras.regularizers import Regularizer
from keras.utils import register_keras_serializable
from google.colab import drive
from datetime import datetime

# fixing random seed for reproducibility
seed = 2022
np.random.seed(seed)

# %%
# Mounting Google Drive to access files
drive.mount('/content/gdrive')
Increasing_BW_data = pd.read_fwf('/content/gdrive/My Drive/Data/Increasing_BW.txt')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Steps below are performing some data_preprocessing

# %%
datasets = [Increasing_BW_data]

# %%
# Defining a function to apply the operation for removing strings from the data
def extract_and_convert_to_float(df):
    for column in df.columns:
      if pd.api.types.is_string_dtype(df[column]):
        df[column] = df[column].str.extract(r'(\d+[.\d]*)').astype(float)
    return df

for df in datasets:
    df = extract_and_convert_to_float(df)

# %%
# Dropping off irrelevant columns and only keeping the relevant
data_frames = [Increasing_BW_data]
for df in data_frames:
   df.drop(columns=df.columns.difference(['Transfer', 'Bandwidth']), inplace=True)

# %%
df['increment'] = range(len(Increasing_BW_data))

# %%
# Dividing 'Transfer' column values by 1024 for data conversion to MBytes
Increasing_BW_data.loc[0:38, 'Transfer'] /= 1024

# %%
# Multiplying 'Bandwidth' column values by 1000 where the value is less than 5 to make uniformity of MBytes/Sec
Increasing_BW_data.loc[Increasing_BW_data['Bandwidth'] < 5, 'Bandwidth'] *= 1000

# %%
# Dropping off outlier points
Increasing_BW_data.drop([1159, 3980], inplace=True)

# %% [markdown]
# # Visualizing the data we shall make predictions on

# %%
import seaborn as sns
# Creating a plot to visualize the data
plt.figure(figsize=(12, 6))
sns.lineplot(x='increment', y='Transfer', data=Increasing_BW_data)
plt.xlabel('Time')
plt.ylabel('Transferred data(MBytes)')
plt.title('Variation of Transferred data with time')
plt.show()

# %%
# Checking the shape of the Data'
Increasing_BW_data.shape
# Out:
# (5593, 3)

# %% [markdown]
# # Perfoming data splitting (Training_set, Validation_set, Test_set)

# %%
# Defining train_size as 70% of the length of the data
train_size = int(0.7 * len(Increasing_BW_data))
# Creating the train_set by selecting the first 70% of the data
train_set = Increasing_BW_data[:train_size]

# %%
# Defining validation_size as 15% of the length of the data
val_size = int(0.15 * len(Increasing_BW_data))
# Creating the val_set by selecting the first 15% of the data
val_set = Increasing_BW_data[train_size:train_size + val_size]

# %%
# Creating the test_set by selecting the data after the train_set and val_set
test_set = Increasing_BW_data[train_size + val_size:]

# %%
# Concatenating train_set and val_set to create train_all_data
train_all = pd.concat([train_set, val_set], axis=0)

# %%
# Extracting data from dataframes, selecting the features
# The labels simply contain the Transferred Trafic

#  Selecting which features to use:

def feature_matrix(df,features):
    numsamples = df.shape[0]
    numfeatures = len(features)

    fm = np.zeros((numsamples,numfeatures))
    for idx in range(numfeatures):
        fm[:,idx] = df[features[idx]]
    return fm

features = ['Bandwidth', 'Transfer']

# Important: Tensorflow 2.x gives an error omitting
# the np.asarray(...,,dtype=np.float32)

# trainining  and validation data
train_values = np.asarray(feature_matrix(train_set,features),dtype=np.float32)
train_labels = np.asarray(train_set['Transfer'],dtype=np.float32)

val_values = np.asarray(feature_matrix(val_set,features),dtype=np.float32)
val_labels = np.asarray(val_set['Transfer'],dtype=np.float32)

# train_all_data for retraining before testing
train_all_values = np.asarray(feature_matrix(train_all,features),dtype=np.float32)
train_all_labels = np.asarray(train_all['Transfer'],dtype=np.float32)

# test data
test_values = np.asarray(feature_matrix(test_set,features),dtype=np.float32)
test_labels = np.asarray(test_set['Transfer'],dtype=np.float32)



# checking
print(train_values.shape)
print(train_labels.shape)

print(val_values.shape)
print(val_labels.shape)

print(train_all_values.shape)
print(train_all_labels.shape)

print(test_values.shape)
print(test_labels.shape)
# Out:
# (3915, 2)
# (3915,)
# (838, 2)
# (838,)
# (4753, 2)
# (4753,)
# (840, 2)
# (840,)

# %%
# Creating a MinMaxScaler instance SS1 and fitting it to train_values
SS1 = MinMaxScaler()
SS1.fit(train_values)

# Transforming train_values and val_values using SS1
train_scaled = SS1.transform(train_values)
val_scaled = SS1.transform(val_values)

# Creating another MinMaxScaler instance SS2 and fitting it to train_all_values
SS2 = MinMaxScaler()
SS2.fit(train_all_values)

# Transforming train_all_values and test_values using SS2
train_all_scaled = SS2.transform(train_all_values)
test_scaled = SS2.transform(test_values)

# %% [markdown]
# # Setting the desired WINDOW_SIZE (how much we go back in the past)

# %%
WINDOW_SIZE = 1

# %%
# Function to create our windowed dataset with ahead set to 2 = 1 seconds
def create_dataset_windowed(features, labels, ahead=2, window_size=WINDOW_SIZE, max_window_size=WINDOW_SIZE):
    samples = features.shape[0]-ahead-(max_window_size-1)
    window_size = min(max(window_size,1),max_window_size)

    dataX = []
    for i in range(samples):
        a = features[(i+max_window_size-window_size):(i+max_window_size), :]
        dataX.append(a)
    return np.array(dataX), labels[ahead+max_window_size-1:]

# %% [markdown]
# **Creating the windowed data_sets for training**

# %%
# Creating windowed datasets for training and validation sets
X_train_dense, r_train_dense = create_dataset_windowed(train_scaled, train_labels)
X_val_dense, r_val_dense = create_dataset_windowed(val_scaled, val_labels)

# Printing shapes of the created datasets
print(X_train_dense.shape)
print(r_train_dense.shape)
print(X_val_dense.shape)
print(r_val_dense.shape)
# Out:
# (3913, 1, 2)
# (3913,)
# (836, 1, 2)
# (836,)

# %% [markdown]
# # First training the model on the training and validation sets

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the RNN to 256
HIDDEN_RNN = 256
# regularization
wreg = L1L2(l1=0.001, l2=0.01)

LSTMmodel = Sequential()

# Adding layers to the model
LSTMmodel.add(Dense(32, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTMmodel.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTMmodel.add(Dense(16,activation='relu'))
LSTMmodel.add(Dense(8,activation='relu'))
LSTMmodel.add(Dense(4,activation='relu'))
LSTMmodel.add(Dense(1))
LSTMmodel.summary()

LSTMmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=16
epochs=40

# Training the model
LSTMhistory = LSTMmodel.fit(X_train_dense, r_train_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_dense, r_val_dense),
          shuffle=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 1, 32)             96
#
#  lstm_2 (LSTM)               (None, 256)               295936
#
#  dense_11 (Dense)            (None, 16)                4112
#
#  dense_12 (Dense)            (None, 8)                 136
#
#  dense_13 (Dense)            (None, 4)                 36
#
#  dense_14 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 300321 (1.15 MB)
# Trainable params: 300321 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 245/245 [==============================] - 5s 11ms/step - loss: 32.8562 - mae: 31.5202 - mse: 1338.3923 - val_loss: 70.2257 - val_mae: 69.2772 - val_mse: 4815.3057
# Epoch 2/40
# 245/245 [==============================] - 2s 8ms/step - loss: 26.5530 - mae: 25.6410 - mse: 940.0437 - val_loss: 44.9762 - val_mae: 43.8559 - val_mse: 1932.4989
# Epoch 3/40
# 245/245 [==============================] - 1s 6ms/step - loss: 9.0324 - mae: 7.5364 - mse: 100.9107 - val_loss: 11.2856 - val_mae: 9.6556 - val_mse: 95.7780
# Epoch 4/40
# 245/245 [==============================] - 1s 6ms/step - loss: 4.7953 - mae: 3.1418 - mse: 14.6934 - val_loss: 6.0324 - val_mae: 4.3437 - val_mse: 19.6218
# Epoch 5/40
# 245/245 [==============================] - 1s 6ms/step - loss: 2.7300 - mae: 1.0103 - mse: 2.4956 - val_loss: 2.4197 - val_mae: 0.7298 - val_mse: 0.7043
# Epoch 6/40
# 245/245 [==============================] - 1s 6ms/step - loss: 2.1253 - mae: 0.5131 - mse: 0.8121 - val_loss: 2.5386 - val_mae: 0.9981 - val_mse: 1.2139
# Epoch 7/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.8972 - mae: 0.4200 - mse: 0.5175 - val_loss: 2.5900 - val_mae: 1.1727 - val_mse: 1.6484
# Epoch 8/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.7188 - mae: 0.3552 - mse: 0.3436 - val_loss: 2.7686 - val_mae: 1.4572 - val_mse: 2.4511
# Epoch 9/40
# 245/245 [==============================] - 2s 7ms/step - loss: 1.5781 - mae: 0.3129 - mse: 0.2463 - val_loss: 2.6225 - val_mae: 1.3997 - val_mse: 2.3303
# Epoch 10/40
# 245/245 [==============================] - 2s 8ms/step - loss: 1.4698 - mae: 0.2893 - mse: 0.1920 - val_loss: 3.0375 - val_mae: 1.8970 - val_mse: 4.0177
# Epoch 11/40
# 245/245 [==============================] - 2s 7ms/step - loss: 1.3820 - mae: 0.2752 - mse: 0.1647 - val_loss: 3.0749 - val_mae: 2.0041 - val_mse: 4.4684
# Epoch 12/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.3113 - mae: 0.2692 - mse: 0.1509 - val_loss: 2.7840 - val_mae: 1.7697 - val_mse: 3.5781
# Epoch 13/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.2478 - mae: 0.2629 - mse: 0.1463 - val_loss: 2.9433 - val_mae: 1.9855 - val_mse: 4.4082
# Epoch 14/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.1895 - mae: 0.2548 - mse: 0.1372 - val_loss: 2.5807 - val_mae: 1.6654 - val_mse: 3.2084
# Epoch 15/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.1369 - mae: 0.2463 - mse: 0.1325 - val_loss: 2.5450 - val_mae: 1.6720 - val_mse: 3.2197
# Epoch 16/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.0934 - mae: 0.2422 - mse: 0.1294 - val_loss: 2.7603 - val_mae: 1.9290 - val_mse: 4.1527
# Epoch 17/40
# 245/245 [==============================] - 1s 6ms/step - loss: 1.0473 - mae: 0.2326 - mse: 0.1267 - val_loss: 2.6785 - val_mae: 1.8811 - val_mse: 3.9489
# Epoch 18/40
# 245/245 [==============================] - 2s 7ms/step - loss: 1.0062 - mae: 0.2233 - mse: 0.1179 - val_loss: 2.5144 - val_mae: 1.7467 - val_mse: 3.4347
# Epoch 19/40
# 245/245 [==============================] - 2s 8ms/step - loss: 0.9647 - mae: 0.2121 - mse: 0.1118 - val_loss: 2.2589 - val_mae: 1.5184 - val_mse: 2.6644
# Epoch 20/40
# 245/245 [==============================] - 2s 7ms/step - loss: 0.9311 - mae: 0.2055 - mse: 0.1093 - val_loss: 2.4632 - val_mae: 1.7519 - val_mse: 3.4288
# Epoch 21/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.8965 - mae: 0.1961 - mse: 0.1035 - val_loss: 2.2688 - val_mae: 1.5802 - val_mse: 2.8288
# Epoch 22/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.8634 - mae: 0.1863 - mse: 0.0996 - val_loss: 2.2405 - val_mae: 1.5738 - val_mse: 2.7876
# Epoch 23/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.8321 - mae: 0.1758 - mse: 0.0936 - val_loss: 2.1122 - val_mae: 1.4654 - val_mse: 2.4382
# Epoch 24/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.8022 - mae: 0.1654 - mse: 0.0899 - val_loss: 2.1025 - val_mae: 1.4746 - val_mse: 2.4480
# Epoch 25/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.7736 - mae: 0.1542 - mse: 0.0866 - val_loss: 2.0071 - val_mae: 1.3955 - val_mse: 2.2000
# Epoch 26/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.7520 - mae: 0.1479 - mse: 0.0826 - val_loss: 1.8016 - val_mae: 1.2044 - val_mse: 1.6812
# Epoch 27/40
# 245/245 [==============================] - 2s 8ms/step - loss: 0.7305 - mae: 0.1407 - mse: 0.0794 - val_loss: 1.8582 - val_mae: 1.2757 - val_mse: 1.8449
# Epoch 28/40
# 245/245 [==============================] - 2s 9ms/step - loss: 0.7130 - mae: 0.1372 - mse: 0.0779 - val_loss: 1.7372 - val_mae: 1.1678 - val_mse: 1.5695
# Epoch 29/40
# 245/245 [==============================] - 2s 6ms/step - loss: 0.6900 - mae: 0.1269 - mse: 0.0750 - val_loss: 1.6974 - val_mae: 1.1410 - val_mse: 1.4976
# Epoch 30/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6779 - mae: 0.1273 - mse: 0.0747 - val_loss: 1.6588 - val_mae: 1.1144 - val_mse: 1.4285
# Epoch 31/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6630 - mae: 0.1240 - mse: 0.0736 - val_loss: 1.5496 - val_mae: 1.0156 - val_mse: 1.2051
# Epoch 32/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6515 - mae: 0.1227 - mse: 0.0728 - val_loss: 1.4999 - val_mae: 0.9762 - val_mse: 1.1197
# Epoch 33/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6339 - mae: 0.1150 - mse: 0.0707 - val_loss: 1.5372 - val_mae: 1.0233 - val_mse: 1.2088
# Epoch 34/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6251 - mae: 0.1153 - mse: 0.0707 - val_loss: 1.3607 - val_mae: 0.8546 - val_mse: 0.8768
# Epoch 35/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.6151 - mae: 0.1145 - mse: 0.0696 - val_loss: 1.4708 - val_mae: 0.9748 - val_mse: 1.0992
# Epoch 36/40
# 245/245 [==============================] - 2s 8ms/step - loss: 0.6008 - mae: 0.1086 - mse: 0.0687 - val_loss: 1.4363 - val_mae: 0.9488 - val_mse: 1.0441
# Epoch 37/40
# 245/245 [==============================] - 2s 9ms/step - loss: 0.5922 - mae: 0.1083 - mse: 0.0686 - val_loss: 1.2929 - val_mae: 0.8127 - val_mse: 0.7945
# Epoch 38/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.5823 - mae: 0.1064 - mse: 0.0676 - val_loss: 1.3843 - val_mae: 0.9123 - val_mse: 0.9655
# Epoch 39/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.5733 - mae: 0.1050 - mse: 0.0676 - val_loss: 1.3945 - val_mae: 0.9303 - val_mse: 0.9965
# Epoch 40/40
# 245/245 [==============================] - 1s 6ms/step - loss: 0.5664 - mae: 0.1053 - mse: 0.0675 - val_loss: 1.4082 - val_mae: 0.9520 - val_mse: 1.0364

# %%
# Plotting the history of Mean Absolute Error for training and validation sets
def plot_history(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Validation MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and validation loss curves

# %%
plot_history(LSTMhistory)

# %% [markdown]
# # Combining the training set and the validation set to create a larger training dataset.Trainining the model on this combined dataset to utilize all available data.Performing validation on the final test set to assess the model's performance on unseen data.

# %%
# Creating a windowed data_set
X_train_all_dense,r_train_all_dense = create_dataset_windowed(train_all_scaled,train_all_labels)
X_test_dense,r_test_dense = create_dataset_windowed(test_scaled,test_labels)

print(X_train_all_dense.shape)
print(r_train_all_dense.shape)
print(X_test_dense.shape)
print(r_test_dense.shape)
# Out:
# (4751, 1, 2)
# (4751,)
# (838, 1, 2)
# (838,)

# %% [markdown]
# # Training the model on the whole training set (train + validation sets) and evaluating it on the test set.

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer  to 256
HIDDEN_RNN = 256
# applying regularization
wreg = L1L2(l1=0.001, l2=0.01)

LSTM_model = Sequential()

# Adding layers to the model
LSTM_model.add(Dense(32, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTM_model.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTM_model.add(Dense(16,activation='relu'))
LSTM_model.add(Dense(8,activation='relu'))
LSTM_model.add(Dense(4,activation='relu'))
LSTM_model.add(Dense(1))
LSTM_model.summary()

LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=16
epochs=40

# Training the model
LSTM_history = LSTM_model.fit(X_train_all_dense, r_train_all_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_dense, r_test_dense),
          shuffle=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 1, 32)             96
#
#  lstm_5 (LSTM)               (None, 256)               295936
#
#  dense_26 (Dense)            (None, 16)                4112
#
#  dense_27 (Dense)            (None, 8)                 136
#
#  dense_28 (Dense)            (None, 4)                 36
#
#  dense_29 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 300321 (1.15 MB)
# Trainable params: 300321 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 297/297 [==============================] - 5s 8ms/step - loss: 39.4070 - mae: 38.1453 - mse: 1963.6630 - val_loss: 81.9223 - val_mae: 81.0239 - val_mse: 6581.9297
# Epoch 2/40
# 297/297 [==============================] - 2s 6ms/step - loss: 24.1127 - mae: 22.9056 - mse: 866.6350 - val_loss: 18.8570 - val_mae: 17.0682 - val_mse: 295.8773
# Epoch 3/40
# 297/297 [==============================] - 2s 6ms/step - loss: 6.6294 - mae: 4.8077 - mse: 33.3806 - val_loss: 8.8965 - val_mae: 7.0470 - val_mse: 50.9881
# Epoch 4/40
# 297/297 [==============================] - 2s 7ms/step - loss: 3.3458 - mae: 1.4395 - mse: 4.8215 - val_loss: 2.7054 - val_mae: 0.8181 - val_mse: 0.9350
# Epoch 5/40
# 297/297 [==============================] - 3s 8ms/step - loss: 2.4124 - mae: 0.6185 - mse: 1.1469 - val_loss: 2.7030 - val_mae: 0.9950 - val_mse: 1.3156
# Epoch 6/40
# 297/297 [==============================] - 2s 6ms/step - loss: 2.1323 - mae: 0.5022 - mse: 0.7105 - val_loss: 3.0157 - val_mae: 1.4599 - val_mse: 2.5329
# Epoch 7/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.9171 - mae: 0.4248 - mse: 0.4497 - val_loss: 2.9562 - val_mae: 1.5236 - val_mse: 2.7731
# Epoch 8/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.7528 - mae: 0.3779 - mse: 0.3126 - val_loss: 3.4821 - val_mae: 2.1627 - val_mse: 5.2065
# Epoch 9/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.6321 - mae: 0.3573 - mse: 0.2536 - val_loss: 3.2669 - val_mae: 2.0357 - val_mse: 4.6998
# Epoch 10/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.5305 - mae: 0.3401 - mse: 0.2197 - val_loss: 3.3199 - val_mae: 2.1680 - val_mse: 5.2702
# Epoch 11/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.4490 - mae: 0.3328 - mse: 0.2075 - val_loss: 3.2572 - val_mae: 2.1735 - val_mse: 5.2894
# Epoch 12/40
# 297/297 [==============================] - 3s 9ms/step - loss: 1.3787 - mae: 0.3263 - mse: 0.1967 - val_loss: 3.4259 - val_mae: 2.4047 - val_mse: 6.3577
# Epoch 13/40
# 297/297 [==============================] - 2s 7ms/step - loss: 1.3095 - mae: 0.3133 - mse: 0.1836 - val_loss: 3.1941 - val_mae: 2.2245 - val_mse: 5.5026
# Epoch 14/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.2527 - mae: 0.3070 - mse: 0.1783 - val_loss: 2.9745 - val_mae: 2.0511 - val_mse: 4.7227
# Epoch 15/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.1962 - mae: 0.2966 - mse: 0.1674 - val_loss: 2.6952 - val_mae: 1.8147 - val_mse: 3.7821
# Epoch 16/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.1446 - mae: 0.2876 - mse: 0.1606 - val_loss: 2.8090 - val_mae: 1.9717 - val_mse: 4.3744
# Epoch 17/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.1025 - mae: 0.2839 - mse: 0.1592 - val_loss: 3.0113 - val_mae: 2.2129 - val_mse: 5.3781
# Epoch 18/40
# 297/297 [==============================] - 2s 6ms/step - loss: 1.0574 - mae: 0.2741 - mse: 0.1498 - val_loss: 2.5021 - val_mae: 1.7339 - val_mse: 3.4505
# Epoch 19/40
# 297/297 [==============================] - 2s 8ms/step - loss: 1.0203 - mae: 0.2682 - mse: 0.1433 - val_loss: 2.7047 - val_mae: 1.9689 - val_mse: 4.3139
# Epoch 20/40
# 297/297 [==============================] - 2s 7ms/step - loss: 0.9833 - mae: 0.2613 - mse: 0.1409 - val_loss: 2.2027 - val_mae: 1.4927 - val_mse: 2.6347
# Epoch 21/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.9522 - mae: 0.2573 - mse: 0.1355 - val_loss: 2.6184 - val_mae: 1.9370 - val_mse: 4.1616
# Epoch 22/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.9186 - mae: 0.2486 - mse: 0.1306 - val_loss: 2.3014 - val_mae: 1.6432 - val_mse: 3.0907
# Epoch 23/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.8924 - mae: 0.2461 - mse: 0.1290 - val_loss: 2.0625 - val_mae: 1.4242 - val_mse: 2.3866
# Epoch 24/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.8644 - mae: 0.2389 - mse: 0.1222 - val_loss: 2.4526 - val_mae: 1.8391 - val_mse: 3.7594
# Epoch 25/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.8400 - mae: 0.2344 - mse: 0.1182 - val_loss: 2.3781 - val_mae: 1.7846 - val_mse: 3.5548
# Epoch 26/40
# 297/297 [==============================] - 2s 8ms/step - loss: 0.8181 - mae: 0.2317 - mse: 0.1187 - val_loss: 2.2198 - val_mae: 1.6429 - val_mse: 3.0432
# Epoch 27/40
# 297/297 [==============================] - 2s 8ms/step - loss: 0.7941 - mae: 0.2255 - mse: 0.1142 - val_loss: 1.9420 - val_mae: 1.3804 - val_mse: 2.2252
# Epoch 28/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.7757 - mae: 0.2237 - mse: 0.1129 - val_loss: 2.4244 - val_mae: 1.8828 - val_mse: 3.8915
# Epoch 29/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.7611 - mae: 0.2246 - mse: 0.1141 - val_loss: 1.9297 - val_mae: 1.3994 - val_mse: 2.2729
# Epoch 30/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.7393 - mae: 0.2162 - mse: 0.1085 - val_loss: 2.2693 - val_mae: 1.7551 - val_mse: 3.4087
# Epoch 31/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.7251 - mae: 0.2149 - mse: 0.1067 - val_loss: 1.7691 - val_mae: 1.2643 - val_mse: 1.8908
# Epoch 32/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.7081 - mae: 0.2108 - mse: 0.1042 - val_loss: 1.7052 - val_mae: 1.2129 - val_mse: 1.7594
# Epoch 33/40
# 297/297 [==============================] - 2s 7ms/step - loss: 0.6900 - mae: 0.2043 - mse: 0.1002 - val_loss: 1.6015 - val_mae: 1.1205 - val_mse: 1.5337
# Epoch 34/40
# 297/297 [==============================] - 3s 9ms/step - loss: 0.6848 - mae: 0.2106 - mse: 0.1048 - val_loss: 1.6726 - val_mae: 1.2040 - val_mse: 1.7328
# Epoch 35/40
# 297/297 [==============================] - 2s 7ms/step - loss: 0.6643 - mae: 0.2011 - mse: 0.0998 - val_loss: 1.8484 - val_mae: 1.3905 - val_mse: 2.2124
# Epoch 36/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.6522 - mae: 0.1984 - mse: 0.0970 - val_loss: 1.7359 - val_mae: 1.2875 - val_mse: 1.9292
# Epoch 37/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.6455 - mae: 0.2016 - mse: 0.0986 - val_loss: 1.7024 - val_mae: 1.2635 - val_mse: 1.8624
# Epoch 38/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.6297 - mae: 0.1949 - mse: 0.0956 - val_loss: 1.8071 - val_mae: 1.3772 - val_mse: 2.1602
# Epoch 39/40
# 297/297 [==============================] - 2s 6ms/step - loss: 0.6154 - mae: 0.1894 - mse: 0.0930 - val_loss: 1.5800 - val_mae: 1.1574 - val_mse: 1.5867
# Epoch 40/40
# 297/297 [==============================] - 2s 7ms/step - loss: 0.6086 - mae: 0.1910 - mse: 0.0929 - val_loss: 1.6931 - val_mae: 1.2795 - val_mse: 1.8825

# %%
def plot_history_test(history):
    # Creating a figure with higher DPI for better resolution
    plt.figure(figsize=(5, 3), dpi=200)

    # Plot configuration
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error')
    plt.title('Model Training Loss Curves')
    plt.plot(history.epoch, np.array(history.history['mae']), 'g-', label='Training MAE')
    plt.plot(history.epoch, np.array(history.history['val_mae']), 'r-', label='Test MAE')
    plt.legend()

    # Saving the figure with higher resolution
    plt.savefig('history_plot_high_res.png', format='png', dpi=200)
    plt.show()

# %% [markdown]
# # Plotting the model loss curves

# %%
plot_history_test(LSTM_history)

# %% [markdown]
# # Calculating the average Mean Absolute Error on the test_set

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_all_LSTM = LSTM_model.predict(X_train_all_dense)
y_test_LSTM = LSTM_model.predict(X_test_dense)

# Calculating the mean absolute error from the training_all_dataset and test sets
mae_train_all_LSTM = mean_absolute_error(r_train_all_dense, y_train_all_LSTM)
mae_test_LSTM = mean_absolute_error(r_test_dense, y_test_LSTM)

# Printing the mean absolute error from the training_all_dataeet and test sets
print("\ train_all mae = ", mae_train_all_LSTM,
      "\n Test mae = ", mae_test_LSTM)

# Checking the shapes of the predicted output from the training_all_dataset and test sets
print(y_train_all_LSTM.shape)
print(y_test_LSTM.shape)
# Out:
# 149/149 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 2ms/step
# \ train_all mae =  0.18004718
#  Test mae =  1.2794924
# (4751, 1)
# (838, 1)

# %% [markdown]
# # **PID Integration**
# # Here I integrate the PID which improves our predictions

# %%
# Initializing the PID controller
class PIDController:
    def __init__(self, Kp, Ki, Kd):
        """
        Parameters:
        - Kp (float): Proportional gain coefficient.
        - Ki (float): Integral gain coefficient.
        - Kd (float): Derivative gain coefficient.
        """
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.prev_error = 0 # Previous error initialized to zero
        self.integral = 0 # Integral term initialized to zero

    def compute_control_signal(self, error):
        """
        Computing the control signal based on the current error.

        Parameters:
        - error (float): The current error signal.

        Returns:
        - control_signal (float): The computed control signal.
        """
        self.integral += error
        derivative = error - self.prev_error
        self.prev_error = error
        control_signal = self.Kp * error + self.Ki * self.integral + self.Kd * derivative # Computing the control signal using PID formula
        return control_signal

# Defining PID parameters
Kp = 0.3
Ki = 0.001
Kd = 0.3

# Initializing the PID controller
pid_controller = PIDController(Kp, Ki, Kd)

# Setting reference values
reference_train = r_train_all_dense
reference_test = r_test_dense

# Initializing PID control signals
control_signal_train = 0
control_signal_test = 0

y_train_all_LSTM_new = []
y_test_LSTM_new = []

# PID control loop
for i in range(len(X_train_all_dense)):
    error_train = reference_train[i] - y_train_all_LSTM[i]
    control_signal_train = pid_controller.compute_control_signal(error_train)
    # Applying control signal to model output
    y_train_all_LSTM_new.append(y_train_all_LSTM[i] + control_signal_train)

for i in range(len(X_test_dense)):
    error_test = reference_test[i] - y_test_LSTM[i]
    control_signal_test = pid_controller.compute_control_signal(error_test)
    # Applying control signal to model output
    y_test_LSTM_new.append(y_test_LSTM[i] + control_signal_test)


# PID Mean Absolute Error
mae_train_all_LSTM_new = mean_absolute_error(reference_train, y_train_all_LSTM_new)
mae_test_LSTM_new = mean_absolute_error(reference_test, y_test_LSTM_new)

# printing MAE results for comparison
print(f"Old MAE for train: {mae_train_all_LSTM}")
print(f"Old MAE for test: {mae_test_LSTM}")
print(f"New(PID) MAE for train: {mae_train_all_LSTM_new}")
print(f"New(PID) MAE for test: {mae_test_LSTM_new}")
# Out:
# Old MAE for train: 0.1800471842288971
# Old MAE for test: 1.2794923782348633
# New(PID) MAE for train: 0.1331331878900528
# New(PID) MAE for test: 0.163504496216774

# %% [markdown]
# # Plotting the predictions

# %%
plt.figure(figsize=(10, 5), dpi=300) 

# Plotting the actual and predicted traffic data
plt.plot(r_test_dense[:700], 'k-', label='Actual transferred traffic')
plt.plot(y_test_LSTM[:700], 'r-', label='Predicted transferred traffic 1 second ahead')
plt.plot(y_test_LSTM_new[:700], 'b-', label='Predicted transferred traffic 1 second ahead with PID integration')

# Adding labels, title, and legend
plt.xlabel('Time (Seconds)')
plt.ylabel('Transferred Traffic (MBytes)')
plt.title('Actual vs. Predicted transferred traffic')
plt.legend()

plt.savefig('traffic_comparison.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# # Displaying a table for the plotted predictions for visualization

# %%
# Extracting values from index 0 to 10 for display in a table for comparizon
r_test_dense_selected = np.array(r_test_dense[0:10])
y_test_LSTM_selected = np.array(y_test_LSTM[0:10])
y_test_LSTM_new_selected = np.array(y_test_LSTM_new[0:10])

# Flattenning the arrays
r_test_dense_1d = r_test_dense_selected.flatten()
y_test_LSTM_1d = y_test_LSTM_selected.flatten()
y_test_LSTM_new_1d = y_test_LSTM_new_selected.flatten()

# Creating DataFrame
data_pred = {
    'Actual_transferred Traffic': r_test_dense_1d,
    'LSTM_Prediction': y_test_LSTM_1d,
    'LSTM_Prediction_with_PID_Integration': y_test_LSTM_new_1d
}
df_pred = pd.DataFrame(data_pred)

# Creating figure and axis
fig, ax = plt.subplots(figsize=(8, 4))

ax.axis('tight')
ax.axis('off')

# Creating the display table
table = ax.table(cellText=df_pred.values,
                 colLabels=df_pred.columns,
                 cellLoc='center',
                 loc='center')

# Setting font size
table.auto_set_font_size(False)
table.set_fontsize(10)

# Adjusting cell heights
table.auto_set_column_width(col=list(range(len(df_pred.columns))))
table.auto_set_column_width(-1)
plt.show()

# %% [markdown]
# # Plotting the the average error for comparison

# %%
# Data to plot
values = {'MAE_without_PID': mae_test_LSTM, 'MAE_PID_Integrated': mae_test_LSTM_new}
colors = ['orange', 'blue']
bar_width = 0.2

# Creating a figure with higher resolution
plt.figure(figsize=(5, 3), dpi=250)

# Plotting the bars
plt.bar(values.keys(), values.values(), color=colors, width=bar_width)

# Setting x positions
x_pos = list(range(len(values)))

# Adding labels and title
plt.ylabel('MAE')
plt.title('Average Mean Absolute Error of predictions 1 second ahead')
plt.xticks(x_pos, values.keys())

plt.grid(True)

plt.savefig('MAE_comparison_high_res.png', format='png', dpi=300)
plt.show()
