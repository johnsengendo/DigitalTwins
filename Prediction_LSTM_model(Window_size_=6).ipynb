# %%
# Importing necessary libraries
import os
import math
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,GRU, Dropout, Lambda, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta, Nadam
from keras import regularizers, backend as K, utils
from keras.regularizers import Regularizer
from keras.utils import register_keras_serializable
from google.colab import drive
from datetime import datetime

# fixing random seed for reproducibility
seed = 2022
np.random.seed(seed)

# %%
# Mounting Google Drive to access files
drive.mount('/content/gdrive')
Increasing_BW_data = pd.read_fwf('/content/gdrive/My Drive/Data/Data_with_BW_Increasing/Increasing_BW.txt')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Steps below are performing some data_preprocessing

# %%
datasets = [Increasing_BW_data]

# %%
# Defining a function to apply the operation for removing strings from the data
def extract_and_convert_to_float(df):
    for column in df.columns:
      if pd.api.types.is_string_dtype(df[column]):
        df[column] = df[column].str.extract(r'(\d+[.\d]*)').astype(float)
    return df

for df in datasets:
    df = extract_and_convert_to_float(df)

# %%
# Dropping off irrelevant columns and only keeping the relevant
data_frames = [Increasing_BW_data]
for df in data_frames:
   df.drop(columns=df.columns.difference(['Transfer', 'Bandwidth']), inplace=True)

# %%
# introducing a new column into the data
df['increment'] = range(len(Increasing_BW_data))
# Dividing 'Transfer' column values by 1024 for data conversion to MBytes
Increasing_BW_data.loc[0:38, 'Transfer'] /= 1024

# %%
# Multiplying 'Bandwidth' column values by 1000 where the value is less than 5 to make uniformity of MBytes/Sec
Increasing_BW_data.loc[Increasing_BW_data['Bandwidth'] < 5, 'Bandwidth'] *= 1000
# Dropping off outlier points
Increasing_BW_data.drop([1159, 3980], inplace=True)

# %% [markdown]
# # Visualizing the data we shall make predictions on

# %%
import seaborn as sns
# Creating a plot to visualize the data
plt.figure(figsize=(12, 6))
sns.lineplot(x='increment', y='Transfer', data=Increasing_BW_data)
plt.xlabel('Time')
plt.ylabel('Transferred data(MBytes)')
plt.title('Variation of Transferred data with time')
plt.show()

# %%
# Checking the shape of the Data
Increasing_BW_data.shape
# Out:
# (5593, 3)

# %% [markdown]
# # Perfoming data splitting (Training_set, Validation_set, Test_set)

# %%
# Defining train_size as 70% of the length of the data & creating the train_set
train_size = int(0.7 * len(Increasing_BW_data))
train_set = Increasing_BW_data[:train_size]

# %%
# Defining validation_size as 15% of the length of the data & reating the val_set
val_size = int(0.15 * len(Increasing_BW_data))
val_set = Increasing_BW_data[train_size:train_size + val_size]

# %%
# Creating the test_set by selecting the data after the train_set and val_set
test_set = Increasing_BW_data[train_size + val_size:]

# %%
# Concatenating train_set and val_set to create train_all_data that will be used in testing
train_all = pd.concat([train_set, val_set], axis=0)

# %%
# Extracting data from dataframes, selecting the features
# The labels simply contain the Transferred Trafic

#  Selecting which features to use:

def feature_matrix(df,features):
    numsamples = df.shape[0]
    numfeatures = len(features)

    fm = np.zeros((numsamples,numfeatures))
    for idx in range(numfeatures):
        fm[:,idx] = df[features[idx]]
    return fm

features = ['Bandwidth', 'Transfer']

# Important: Tensorflow 2.x gives an error omitting
# the np.asarray(...,,dtype=np.float32)

# trainining  and validation data
train_values = np.asarray(feature_matrix(train_set,features),dtype=np.float32)
train_labels = np.asarray(train_set['Transfer'],dtype=np.float32)

val_values = np.asarray(feature_matrix(val_set,features),dtype=np.float32)
val_labels = np.asarray(val_set['Transfer'],dtype=np.float32)

# train_all_data for retraining before testing
train_all_values = np.asarray(feature_matrix(train_all,features),dtype=np.float32)
train_all_labels = np.asarray(train_all['Transfer'],dtype=np.float32)

# test data
test_values = np.asarray(feature_matrix(test_set,features),dtype=np.float32)
test_labels = np.asarray(test_set['Transfer'],dtype=np.float32)



# checking the data
print(train_values.shape)
print(train_labels.shape)

print(val_values.shape)
print(val_labels.shape)

print(train_all_values.shape)
print(train_all_labels.shape)

print(test_values.shape)
print(test_labels.shape)
# Out:
# (3915, 2)
# (3915,)
# (838, 2)
# (838,)
# (4753, 2)
# (4753,)
# (840, 2)
# (840,)

# %%
# Creating a MinMaxScaler instance SS1 and fitting it to train_values
SS1 = MinMaxScaler()
SS1.fit(train_values)

# Transforming train_values and val_values using SS1
train_scaled = SS1.transform(train_values)
val_scaled = SS1.transform(val_values)

# Creating another MinMaxScaler instance SS2 and fitting it to train_all_values
SS2 = MinMaxScaler()
SS2.fit(train_all_values)

# Transforming train_all_values and test_values using SS2
train_all_scaled = SS2.transform(train_all_values)
test_scaled = SS2.transform(test_values)

# %% [markdown]
# # Setting the Window_size

# %%
WINDOW_SIZE = 6

# %%
# Function to create windowed dataset for time series forecasting 4 seconds in the future
def create_dataset_windowed(features, labels, ahead=8, window_size=WINDOW_SIZE, max_window_size=200):
    samples = features.shape[0]-ahead-(max_window_size-1)
    window_size = min(max(window_size,1),max_window_size)

    dataX = []
    for i in range(samples):
        a = features[(i+max_window_size-window_size):(i+max_window_size), :]
        dataX.append(a)
    return np.array(dataX), labels[ahead+max_window_size-1:]

# %% [markdown]
# # Creating the windowed data_sets for training and validation

# %%
X_train_dense, r_train_dense = create_dataset_windowed(train_scaled, train_labels)
X_val_dense, r_val_dense = create_dataset_windowed(val_scaled, val_labels)

# Printing shapes of the created datasets
print(X_train_dense.shape)
print(r_train_dense.shape)
print(X_val_dense.shape)
print(r_val_dense.shape)
# Out:
# (3708, 6, 2)
# (3708,)
# (631, 6, 2)
# (631,)

# %% [markdown]
# # Building and training the model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the LSTM to 256
HIDDEN_RNN = 256
# setting regularisers 
wreg = L1L2(l1=0.001, l2=0.01)

LSTMmodel = Sequential()

# Adding layers to the model
LSTMmodel.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTMmodel.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTMmodel.add(Dense(32,activation='relu'))
LSTMmodel.add(Dense(16,activation='relu'))
LSTMmodel.add(Dense(8,activation='relu'))
LSTMmodel.add(Dense(1))
LSTMmodel.summary()

LSTMmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTMhistory = LSTMmodel.fit(X_train_dense, r_train_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_dense, r_val_dense),
          shuffle=True)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_100 (Dense)           (None, 6, 64)             192
#
#  lstm_20 (LSTM)              (None, 256)               328704
#
#  dense_101 (Dense)           (None, 32)                8224
#
#  dense_102 (Dense)           (None, 16)                528
#
#  dense_103 (Dense)           (None, 8)                 136
#
#  dense_104 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 116/116 [==============================] - 4s 11ms/step - loss: 34.1944 - mae: 31.0969 - mse: 1266.0216 - val_loss: 61.0036 - val_mae: 58.3382 - val_mse: 3412.5071
# Epoch 2/40
# 116/116 [==============================] - 1s 6ms/step - loss: 16.6923 - mae: 14.4078 - mse: 384.2336 - val_loss: 42.2079 - val_mae: 40.2886 - val_mse: 1632.3247
# Epoch 3/40
# 116/116 [==============================] - 1s 7ms/step - loss: 7.2789 - mae: 5.6639 - mse: 83.0227 - val_loss: 25.6284 - val_mae: 24.2863 - val_mse: 598.2710
# Epoch 4/40
# 116/116 [==============================] - 1s 9ms/step - loss: 3.1534 - mae: 2.0142 - mse: 11.9622 - val_loss: 15.2505 - val_mae: 14.2895 - val_mse: 211.0613
# Epoch 5/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.7734 - mae: 0.9405 - mse: 1.9706 - val_loss: 10.3163 - val_mae: 9.5956 - val_mse: 97.3596
# Epoch 6/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.1611 - mae: 0.5204 - mse: 0.5620 - val_loss: 7.9887 - val_mae: 7.4169 - val_mse: 59.0308
# Epoch 7/40
# 116/116 [==============================] - 1s 8ms/step - loss: 0.9077 - mae: 0.3831 - mse: 0.2666 - val_loss: 6.7024 - val_mae: 6.2167 - val_mse: 42.1029
# Epoch 8/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.8593 - mae: 0.3958 - mse: 0.2658 - val_loss: 6.4413 - val_mae: 5.9940 - val_mse: 38.9986
# Epoch 9/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7894 - mae: 0.3519 - mse: 0.2114 - val_loss: 5.4481 - val_mae: 5.0197 - val_mse: 28.3660
# Epoch 10/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7760 - mae: 0.3553 - mse: 0.2084 - val_loss: 5.4088 - val_mae: 4.9954 - val_mse: 27.8702
# Epoch 11/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7159 - mae: 0.3089 - mse: 0.1641 - val_loss: 5.0730 - val_mae: 4.6723 - val_mse: 24.6310
# Epoch 12/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7261 - mae: 0.3309 - mse: 0.1864 - val_loss: 5.2435 - val_mae: 4.8538 - val_mse: 26.1235
# Epoch 13/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7015 - mae: 0.3166 - mse: 0.1714 - val_loss: 4.8266 - val_mae: 4.4467 - val_mse: 22.3429
# Epoch 14/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6781 - mae: 0.3026 - mse: 0.1588 - val_loss: 4.5919 - val_mae: 4.2207 - val_mse: 20.3215
# Epoch 15/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6845 - mae: 0.3173 - mse: 0.1730 - val_loss: 4.8902 - val_mae: 4.5268 - val_mse: 22.7501
# Epoch 16/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6608 - mae: 0.3011 - mse: 0.1568 - val_loss: 4.1966 - val_mae: 3.8403 - val_mse: 17.1211
# Epoch 17/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6543 - mae: 0.3016 - mse: 0.1595 - val_loss: 4.6615 - val_mae: 4.3120 - val_mse: 20.7293
# Epoch 18/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6954 - mae: 0.3489 - mse: 0.2044 - val_loss: 4.4977 - val_mae: 4.1543 - val_mse: 19.3765
# Epoch 19/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6589 - mae: 0.3182 - mse: 0.1708 - val_loss: 4.0601 - val_mae: 3.7221 - val_mse: 16.0204
# Epoch 20/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.6697 - mae: 0.3341 - mse: 0.1853 - val_loss: 4.4753 - val_mae: 4.1425 - val_mse: 19.1937
# Epoch 21/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.6358 - mae: 0.3052 - mse: 0.1600 - val_loss: 4.0372 - val_mae: 3.7091 - val_mse: 15.8219
# Epoch 22/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.6150 - mae: 0.2890 - mse: 0.1486 - val_loss: 3.8914 - val_mae: 3.5676 - val_mse: 14.7552
# Epoch 23/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5962 - mae: 0.2748 - mse: 0.1381 - val_loss: 4.0285 - val_mae: 3.7094 - val_mse: 15.6907
# Epoch 24/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6404 - mae: 0.3230 - mse: 0.1818 - val_loss: 4.2525 - val_mae: 3.9371 - val_mse: 17.3441
# Epoch 25/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6074 - mae: 0.2940 - mse: 0.1514 - val_loss: 3.8992 - val_mae: 3.5878 - val_mse: 14.7535
# Epoch 26/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6116 - mae: 0.3019 - mse: 0.1594 - val_loss: 3.6448 - val_mae: 3.3369 - val_mse: 13.0067
# Epoch 27/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5743 - mae: 0.2682 - mse: 0.1330 - val_loss: 3.7492 - val_mae: 3.4450 - val_mse: 13.6613
# Epoch 28/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5908 - mae: 0.2882 - mse: 0.1441 - val_loss: 3.9007 - val_mae: 3.5999 - val_mse: 14.6858
# Epoch 29/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5836 - mae: 0.2842 - mse: 0.1429 - val_loss: 3.8126 - val_mae: 3.5149 - val_mse: 14.0580
# Epoch 30/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6071 - mae: 0.3109 - mse: 0.1655 - val_loss: 3.8540 - val_mae: 3.5593 - val_mse: 14.3668
# Epoch 31/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5793 - mae: 0.2862 - mse: 0.1448 - val_loss: 3.7921 - val_mae: 3.5006 - val_mse: 13.9282
# Epoch 32/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5541 - mae: 0.2640 - mse: 0.1327 - val_loss: 3.3915 - val_mae: 3.1027 - val_mse: 11.3300
# Epoch 33/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5920 - mae: 0.3047 - mse: 0.1633 - val_loss: 3.6179 - val_mae: 3.3321 - val_mse: 12.7664
# Epoch 34/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5862 - mae: 0.3015 - mse: 0.1593 - val_loss: 3.8759 - val_mae: 3.5921 - val_mse: 14.5030
# Epoch 35/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6106 - mae: 0.3284 - mse: 0.1920 - val_loss: 3.2017 - val_mae: 2.9204 - val_mse: 10.2700
# Epoch 36/40
# 116/116 [==============================] - 1s 8ms/step - loss: 0.6001 - mae: 0.3205 - mse: 0.1832 - val_loss: 3.6689 - val_mae: 3.3906 - val_mse: 13.1027
# Epoch 37/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.5277 - mae: 0.2505 - mse: 0.1234 - val_loss: 3.4751 - val_mae: 3.1991 - val_mse: 11.8198
# Epoch 38/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.5422 - mae: 0.2673 - mse: 0.1316 - val_loss: 3.3154 - val_mae: 3.0418 - val_mse: 10.8422
# Epoch 39/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.5435 - mae: 0.2710 - mse: 0.1326 - val_loss: 3.8024 - val_mae: 3.5308 - val_mse: 13.9368
# Epoch 40/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6047 - mae: 0.3342 - mse: 0.2056 - val_loss: 3.0143 - val_mae: 2.7450 - val_mse: 9.1295

# %%
# Plotting the history of Mean Absolute Error for training and validation sets
def plot_history(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Validation MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and validation loss curves

# %%
plot_history(LSTMhistory)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and validation

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_LSTM = LSTMmodel.predict(X_train_dense)
y_val_LSTM = LSTMmodel.predict(X_val_dense)

# Calculating the mean absolute error from the training and validation set
mae_train_LSTM = mean_absolute_error(r_train_dense, y_train_LSTM)
mae_val_LSTM = mean_absolute_error(r_val_dense, y_val_LSTM)

# Printing the mean absolute error from the training and validation set
print("\"Current Network throuput\n train mae = ", mae_train_LSTM,
      "\n validation mae = ", mae_val_LSTM)

# Printing the shapes of the predicted output from the training and validation set
print(y_train_LSTM.shape)
print(y_val_LSTM.shape)
# Out:
# 116/116 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 0s 2ms/step
# "Current Network throuput
#  train mae =  0.33273786
#  validation mae =  2.7449858
# (3708, 1)
# (631, 1)

# %% [markdown]
# # Ploting out predictions on the validation set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions

scaled_predictions = scale_predictions_to_labels(r_val_dense[:700], y_val_LSTM[:700, 0])

# Now plotting the labels and predictions
plt.figure(figsize=(10, 5))
plt.plot(r_val_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Validation set)')  # Adding a title for context
plt.legend()
plt.show()

# %% [markdown]
# # Combining the training set and the validation set to create a larger training dataset.Trainining the model on this combined dataset to utilize all available data. Performing validation on the final test_set to assess the model's performance on unseen data.

# %%
# Creating our windowed data_set
X_train_all_dense,r_train_all_dense = create_dataset_windowed(train_all_scaled,train_all_labels)
X_test_dense,r_test_dense = create_dataset_windowed(test_scaled,test_labels)

print(X_train_all_dense.shape)
print(r_train_all_dense.shape)
print(X_test_dense.shape)
print(r_test_dense.shape)
# Out:
# (4546, 6, 2)
# (4546,)
# (633, 6, 2)
# (633,)

# %% [markdown]
# # Building and training the Model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the RNN to 256
HIDDEN_RNN = 256
# setting regularisers 
wreg = L1L2(l1=0.001, l2=0.01)

LSTM_model = Sequential()

# Adding layers to the model
LSTM_model.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTM_model.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTM_model.add(Dense(32,activation='relu'))
LSTM_model.add(Dense(16,activation='relu'))
LSTM_model.add(Dense(8,activation='relu'))
LSTM_model.add(Dense(1))
LSTM_model.summary()

LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTM_history = LSTM_model.fit(X_train_all_dense, r_train_all_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_dense, r_test_dense),
          shuffle=True)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_105 (Dense)           (None, 6, 64)             192
#
#  lstm_21 (LSTM)              (None, 256)               328704
#
#  dense_106 (Dense)           (None, 32)                8224
#
#  dense_107 (Dense)           (None, 16)                528
#
#  dense_108 (Dense)           (None, 8)                 136
#
#  dense_109 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 143/143 [==============================] - 4s 10ms/step - loss: 38.3507 - mae: 35.3280 - mse: 1710.6707 - val_loss: 67.4645 - val_mae: 64.9418 - val_mse: 4227.8569
# Epoch 2/40
# 143/143 [==============================] - 1s 6ms/step - loss: 16.3904 - mae: 14.3126 - mse: 413.9783 - val_loss: 42.9844 - val_mae: 41.3125 - val_mse: 1716.8361
# Epoch 3/40
# 143/143 [==============================] - 1s 6ms/step - loss: 6.1591 - mae: 4.7946 - mse: 63.9774 - val_loss: 23.4723 - val_mae: 22.3749 - val_mse: 509.1632
# Epoch 4/40
# 143/143 [==============================] - 1s 8ms/step - loss: 2.7698 - mae: 1.8542 - mse: 8.5030 - val_loss: 14.7831 - val_mae: 14.0217 - val_mse: 202.4273
# Epoch 5/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.7486 - mae: 1.0877 - mse: 2.3185 - val_loss: 9.9870 - val_mae: 9.4098 - val_mse: 93.1261
# Epoch 6/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.2535 - mae: 0.7260 - mse: 1.0167 - val_loss: 7.5046 - val_mae: 7.0144 - val_mse: 52.7894
# Epoch 7/40
# 143/143 [==============================] - 1s 8ms/step - loss: 1.0135 - mae: 0.5399 - mse: 0.5410 - val_loss: 6.5933 - val_mae: 6.1321 - val_mse: 40.3963
# Epoch 8/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9256 - mae: 0.4740 - mse: 0.3852 - val_loss: 5.2853 - val_mae: 4.8427 - val_mse: 26.1007
# Epoch 9/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.8148 - mae: 0.3794 - mse: 0.2520 - val_loss: 5.1526 - val_mae: 4.7243 - val_mse: 24.6213
# Epoch 10/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.8076 - mae: 0.3852 - mse: 0.2491 - val_loss: 4.9389 - val_mae: 4.5227 - val_mse: 22.6100
# Epoch 11/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.7259 - mae: 0.3149 - mse: 0.1745 - val_loss: 4.4462 - val_mae: 4.0405 - val_mse: 18.4349
# Epoch 12/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.7228 - mae: 0.3216 - mse: 0.1756 - val_loss: 4.5504 - val_mae: 4.1541 - val_mse: 19.2118
# Epoch 13/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.7344 - mae: 0.3422 - mse: 0.1998 - val_loss: 3.9500 - val_mae: 3.5620 - val_mse: 14.7143
# Epoch 14/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6877 - mae: 0.3036 - mse: 0.1610 - val_loss: 3.9538 - val_mae: 3.5736 - val_mse: 14.6879
# Epoch 15/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6847 - mae: 0.3079 - mse: 0.1634 - val_loss: 4.6173 - val_mae: 4.2442 - val_mse: 19.7404
# Epoch 16/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.7296 - mae: 0.3596 - mse: 0.2235 - val_loss: 4.3293 - val_mae: 3.9625 - val_mse: 17.4718
# Epoch 17/40
# 143/143 [==============================] - 2s 11ms/step - loss: 0.6515 - mae: 0.2877 - mse: 0.1463 - val_loss: 4.5346 - val_mae: 4.1735 - val_mse: 19.0521
# Epoch 18/40
# 143/143 [==============================] - 2s 13ms/step - loss: 0.7508 - mae: 0.3926 - mse: 0.2612 - val_loss: 3.9745 - val_mae: 3.6194 - val_mse: 14.8643
# Epoch 19/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.6712 - mae: 0.3185 - mse: 0.1783 - val_loss: 4.0460 - val_mae: 3.6960 - val_mse: 15.3531
# Epoch 20/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6661 - mae: 0.3184 - mse: 0.1725 - val_loss: 3.2388 - val_mae: 2.8932 - val_mse: 10.1985
# Epoch 21/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6584 - mae: 0.3155 - mse: 0.1690 - val_loss: 3.5537 - val_mae: 3.2132 - val_mse: 12.0369
# Epoch 22/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6617 - mae: 0.3231 - mse: 0.1818 - val_loss: 3.5274 - val_mae: 3.1912 - val_mse: 11.8836
# Epoch 23/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6571 - mae: 0.3228 - mse: 0.1806 - val_loss: 4.0489 - val_mae: 3.7167 - val_mse: 15.3792
# Epoch 24/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6721 - mae: 0.3417 - mse: 0.1988 - val_loss: 4.1244 - val_mae: 3.7960 - val_mse: 15.9690
# Epoch 25/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6417 - mae: 0.3151 - mse: 0.1704 - val_loss: 3.6107 - val_mae: 3.2862 - val_mse: 12.4343
# Epoch 26/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6121 - mae: 0.2893 - mse: 0.1481 - val_loss: 4.0288 - val_mae: 3.7073 - val_mse: 15.2690
# Epoch 27/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6408 - mae: 0.3213 - mse: 0.1818 - val_loss: 3.5096 - val_mae: 3.1920 - val_mse: 11.8032
# Epoch 28/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6136 - mae: 0.2974 - mse: 0.1584 - val_loss: 3.5113 - val_mae: 3.1969 - val_mse: 11.7564
# Epoch 29/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.6242 - mae: 0.3112 - mse: 0.1651 - val_loss: 3.2915 - val_mae: 2.9800 - val_mse: 10.4096
# Epoch 30/40
# 143/143 [==============================] - 1s 8ms/step - loss: 0.6389 - mae: 0.3288 - mse: 0.1879 - val_loss: 3.4777 - val_mae: 3.1693 - val_mse: 11.5364
# Epoch 31/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.6045 - mae: 0.2975 - mse: 0.1536 - val_loss: 2.8629 - val_mae: 2.5570 - val_mse: 8.0920
# Epoch 32/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.5904 - mae: 0.2862 - mse: 0.1451 - val_loss: 2.9570 - val_mae: 2.6540 - val_mse: 8.5717
# Epoch 33/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5947 - mae: 0.2932 - mse: 0.1512 - val_loss: 3.0682 - val_mae: 2.7680 - val_mse: 9.1336
# Epoch 34/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5952 - mae: 0.2964 - mse: 0.1529 - val_loss: 3.3173 - val_mae: 3.0199 - val_mse: 10.5132
# Epoch 35/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5815 - mae: 0.2852 - mse: 0.1435 - val_loss: 3.3933 - val_mae: 3.0986 - val_mse: 10.9713
# Epoch 36/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.5811 - mae: 0.2873 - mse: 0.1448 - val_loss: 3.7571 - val_mae: 3.4643 - val_mse: 13.2978
# Epoch 37/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.5764 - mae: 0.2850 - mse: 0.1421 - val_loss: 2.9811 - val_mae: 2.6911 - val_mse: 8.6143
# Epoch 38/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.5813 - mae: 0.2923 - mse: 0.1491 - val_loss: 3.0725 - val_mae: 2.7847 - val_mse: 9.0833
# Epoch 39/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.5654 - mae: 0.2788 - mse: 0.1412 - val_loss: 2.9761 - val_mae: 2.6906 - val_mse: 8.5760
# Epoch 40/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.5837 - mae: 0.2993 - mse: 0.1562 - val_loss: 3.1185 - val_mae: 2.8352 - val_mse: 9.3463

# %%
# Plotting the history of Mean Absolute Error for training_all_dataset and test sets
def plot_history_test(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train_all MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Test MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and test loss curves

# %%
plot_history_test(LSTM_history)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and testing

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_all_LSTM = LSTM_model.predict(X_train_all_dense)
y_test_LSTM = LSTM_model.predict(X_test_dense)

# Calculating the mean absolute error from the training_all_dataset and test_set
mae_train_all_LSTM = mean_absolute_error(r_train_all_dense, y_train_all_LSTM)
mae_test_LSTM = mean_absolute_error(r_test_dense, y_test_LSTM)

# Printing the mean absolute error from the training_all_dataeet and test_set
print("\"Current Network throuput\" baseline:\n train mae = ", mae_train_all_LSTM,
      "\n validation mae = ", mae_test_LSTM)

# Checking the shapes of the predicted output from the training_all_dataset and test_set
print(y_train_all_LSTM.shape)
print(y_test_LSTM.shape)
# Out:
# 143/143 [==============================] - 1s 4ms/step
# 20/20 [==============================] - 0s 3ms/step
# "Current Network throuput" baseline:
#  train mae =  0.23404601
#  validation mae =  2.835244
# (4546, 1)
# (633, 1)

# %% [markdown]
# # Visualizing the predictions on the test set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions


scaled_predictions = scale_predictions_to_labels(r_test_dense[:700], y_test_LSTM[:700, 0])

# Now plotting the labels and scaled predictions
plt.figure(figsize=(10, 5))
plt.plot(r_test_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Test set)')
plt.legend()
plt.show()
