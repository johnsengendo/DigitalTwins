# %%
# Importing necessary libraries
import os
import math
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,GRU, Dropout, Lambda, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta, Nadam
from keras import regularizers, backend as K, utils
from keras.regularizers import Regularizer
from keras.utils import register_keras_serializable
from google.colab import drive
from datetime import datetime

# fixing random seed for reproducibility
seed = 2022
np.random.seed(seed)

# %%
# Mounting Google Drive to access files
drive.mount('/content/gdrive')
Increasing_BW_data = pd.read_fwf('/content/gdrive/My Drive/Data/Data_with_BW_Increasing/Increasing_BW.txt')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Steps below are performing some data_preprocessing

# %%
datasets = [Increasing_BW_data]

# %%
# Defining a function to apply the operation for removing strings from the data
def extract_and_convert_to_float(df):
    for column in df.columns:
      if pd.api.types.is_string_dtype(df[column]):
        df[column] = df[column].str.extract(r'(\d+[.\d]*)').astype(float)
    return df

for df in datasets:
    df = extract_and_convert_to_float(df)

# %%
# Dropping off irrelevant columns and only keeping the relevant
data_frames = [Increasing_BW_data]
for df in data_frames:
   df.drop(columns=df.columns.difference(['Transfer', 'Bandwidth']), inplace=True)

# %%
# introducing a new column into the data
df['increment'] = range(len(Increasing_BW_data))
# Dividing 'Transfer' column values by 1024 for data conversion to MBytes
Increasing_BW_data.loc[0:38, 'Transfer'] /= 1024

# %%
# Multiplying 'Bandwidth' column values by 1000 where the value is less than 5 to make uniformity of MBytes/Sec
Increasing_BW_data.loc[Increasing_BW_data['Bandwidth'] < 5, 'Bandwidth'] *= 1000
# Dropping off outlier points
Increasing_BW_data.drop([1159, 3980], inplace=True)

# %% [markdown]
# # Visualizing the data we shall make predictions on

# %%
import seaborn as sns
# Creating a plot to visualize the data
plt.figure(figsize=(12, 6))
sns.lineplot(x='increment', y='Transfer', data=Increasing_BW_data)
plt.xlabel('Time')
plt.ylabel('Transferred data(MBytes)')
plt.title('Variation of Transferred data with time')
plt.show()

# %%
# Checking the shape of the Data
Increasing_BW_data.shape
# Out:
# (5593, 3)

# %% [markdown]
# # Perfoming data splitting (Training_set, Validation_set, Test_set)

# %%
# Defining train_size as 70% of the length of the data & creating the train_set
train_size = int(0.7 * len(Increasing_BW_data))
train_set = Increasing_BW_data[:train_size]

# %%
# Defining validation_size as 15% of the length of the data & creating the val_set
val_size = int(0.15 * len(Increasing_BW_data))
val_set = Increasing_BW_data[train_size:train_size + val_size]

# %%
# Creating the test_set by selecting the data after the train_set and val_set
test_set = Increasing_BW_data[train_size + val_size:]

# %%
# Concatenating train_set and val_set to create train_all_data to be used later in testing
train_all = pd.concat([train_set, val_set], axis=0)

# %%
# Extracting data from dataframes, selecting the features
# The labels simply contain the Transferred Trafic

#  Selecting which features to use:

def feature_matrix(df,features):
    numsamples = df.shape[0]
    numfeatures = len(features)

    fm = np.zeros((numsamples,numfeatures))
    for idx in range(numfeatures):
        fm[:,idx] = df[features[idx]]
    return fm

features = ['Bandwidth', 'Transfer']

# Important: Tensorflow 2.x gives an error omitting
# the np.asarray(...,,dtype=np.float32)

# trainining  and validation data
train_values = np.asarray(feature_matrix(train_set,features),dtype=np.float32)
train_labels = np.asarray(train_set['Transfer'],dtype=np.float32)

val_values = np.asarray(feature_matrix(val_set,features),dtype=np.float32)
val_labels = np.asarray(val_set['Transfer'],dtype=np.float32)

# train_all_data for retraining before testing
train_all_values = np.asarray(feature_matrix(train_all,features),dtype=np.float32)
train_all_labels = np.asarray(train_all['Transfer'],dtype=np.float32)

# test data
test_values = np.asarray(feature_matrix(test_set,features),dtype=np.float32)
test_labels = np.asarray(test_set['Transfer'],dtype=np.float32)



# checking our data
print(train_values.shape)
print(train_labels.shape)

print(val_values.shape)
print(val_labels.shape)

print(train_all_values.shape)
print(train_all_labels.shape)

print(test_values.shape)
print(test_labels.shape)
# Out:
# (3915, 2)
# (3915,)
# (838, 2)
# (838,)
# (4753, 2)
# (4753,)
# (840, 2)
# (840,)

# %%
# Creating a MinMaxScaler instance SS1 and fitting it to train_values
SS1 = MinMaxScaler()
SS1.fit(train_values)

# Transforming train_values and val_values using SS1
train_scaled = SS1.transform(train_values)
val_scaled = SS1.transform(val_values)

# Creating another MinMaxScaler instance SS2 and fitting it to train_all_values
SS2 = MinMaxScaler()
SS2.fit(train_all_values)

# Transforming train_all_values and test_values using SS2
train_all_scaled = SS2.transform(train_all_values)
test_scaled = SS2.transform(test_values)

# %% [markdown]
# # Setting the Window_size

# %%
WINDOW_SIZE = 1

# %%
# Function to create windowed dataset for time series forecasting 4 seconds in the future
def create_dataset_windowed(features, labels, ahead=8, window_size=WINDOW_SIZE, max_window_size=200):
    samples = features.shape[0]-ahead-(max_window_size-1)
    window_size = min(max(window_size,1),max_window_size)

    dataX = []
    for i in range(samples):
        a = features[(i+max_window_size-window_size):(i+max_window_size), :]
        dataX.append(a)
    return np.array(dataX), labels[ahead+max_window_size-1:]

# %% [markdown]
# # Creating the windowed data_sets for training and validation

# %%
X_train_dense, r_train_dense = create_dataset_windowed(train_scaled, train_labels)
X_val_dense, r_val_dense = create_dataset_windowed(val_scaled, val_labels)

# Printing shapes of the created datasets
print(X_train_dense.shape)
print(r_train_dense.shape)
print(X_val_dense.shape)
print(r_val_dense.shape)
# Out:
# (3708, 1, 2)
# (3708,)
# (631, 1, 2)
# (631,)

# %% [markdown]
# # Building and training the model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the LSTM to 256
HIDDEN_RNN = 256
# regularisers
wreg = L1L2(l1=0.001, l2=0.01)

LSTMmodel = Sequential()

# Adding layers to the model
LSTMmodel.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTMmodel.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTMmodel.add(Dense(32,activation='relu'))
LSTMmodel.add(Dense(16,activation='relu'))
LSTMmodel.add(Dense(8,activation='relu'))
LSTMmodel.add(Dense(1))
LSTMmodel.summary()

LSTMmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTMhistory = LSTMmodel.fit(X_train_dense, r_train_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_dense, r_val_dense),
          shuffle=True)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_90 (Dense)            (None, 1, 64)             192
#
#  lstm_18 (LSTM)              (None, 256)               328704
#
#  dense_91 (Dense)            (None, 32)                8224
#
#  dense_92 (Dense)            (None, 16)                528
#
#  dense_93 (Dense)            (None, 8)                 136
#
#  dense_94 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 116/116 [==============================] - 5s 12ms/step - loss: 36.5359 - mae: 33.4595 - mse: 1435.0121 - val_loss: 75.3472 - val_mae: 72.7967 - val_mse: 5308.5474
# Epoch 2/40
# 116/116 [==============================] - 1s 7ms/step - loss: 34.4482 - mae: 32.2857 - mse: 1345.3793 - val_loss: 70.6036 - val_mae: 68.7684 - val_mse: 4737.5420
# Epoch 3/40
# 116/116 [==============================] - 1s 7ms/step - loss: 28.4879 - mae: 26.8156 - mse: 969.7206 - val_loss: 52.6023 - val_mae: 50.9908 - val_mse: 2605.7478
# Epoch 4/40
# 116/116 [==============================] - 1s 8ms/step - loss: 13.0195 - mae: 11.2786 - mse: 224.0151 - val_loss: 13.6589 - val_mae: 11.8017 - val_mse: 140.8913
# Epoch 5/40
# 116/116 [==============================] - 1s 7ms/step - loss: 6.1222 - mae: 4.3431 - mse: 26.2283 - val_loss: 9.1904 - val_mae: 7.4685 - val_mse: 56.6479
# Epoch 6/40
# 116/116 [==============================] - 1s 7ms/step - loss: 4.7437 - mae: 3.0621 - mse: 13.8445 - val_loss: 5.9857 - val_mae: 4.3230 - val_mse: 19.0827
# Epoch 7/40
# 116/116 [==============================] - 1s 7ms/step - loss: 3.4257 - mae: 1.7667 - mse: 5.4056 - val_loss: 2.8060 - val_mae: 1.1381 - val_mse: 1.4300
# Epoch 8/40
# 116/116 [==============================] - 1s 7ms/step - loss: 2.4270 - mae: 0.7703 - mse: 1.4574 - val_loss: 1.8589 - val_mae: 0.2350 - val_mse: 0.1000
# Epoch 9/40
# 116/116 [==============================] - 1s 7ms/step - loss: 2.1357 - mae: 0.5638 - mse: 0.7466 - val_loss: 1.8030 - val_mae: 0.2854 - val_mse: 0.1650
# Epoch 10/40
# 116/116 [==============================] - 1s 9ms/step - loss: 1.9463 - mae: 0.4800 - mse: 0.5485 - val_loss: 1.9550 - val_mae: 0.5383 - val_mse: 0.4032
# Epoch 11/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.7787 - mae: 0.4055 - mse: 0.3968 - val_loss: 2.0633 - val_mae: 0.7293 - val_mse: 0.6616
# Epoch 12/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.6456 - mae: 0.3486 - mse: 0.2765 - val_loss: 1.8934 - val_mae: 0.6287 - val_mse: 0.5375
# Epoch 13/40
# 116/116 [==============================] - 1s 8ms/step - loss: 1.5374 - mae: 0.3073 - mse: 0.2088 - val_loss: 2.3654 - val_mae: 1.1673 - val_mse: 1.5338
# Epoch 14/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.4530 - mae: 0.2821 - mse: 0.1722 - val_loss: 2.4930 - val_mae: 1.3498 - val_mse: 2.0104
# Epoch 15/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.3882 - mae: 0.2686 - mse: 0.1502 - val_loss: 2.4721 - val_mae: 1.3763 - val_mse: 2.0944
# Epoch 16/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.3347 - mae: 0.2609 - mse: 0.1411 - val_loss: 2.6608 - val_mae: 1.6103 - val_mse: 2.8098
# Epoch 17/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.2915 - mae: 0.2588 - mse: 0.1387 - val_loss: 2.5164 - val_mae: 1.5018 - val_mse: 2.4718
# Epoch 18/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.2558 - mae: 0.2601 - mse: 0.1383 - val_loss: 2.7746 - val_mae: 1.7982 - val_mse: 3.4631
# Epoch 19/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.2176 - mae: 0.2560 - mse: 0.1342 - val_loss: 2.4977 - val_mae: 1.5509 - val_mse: 2.6320
# Epoch 20/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.1853 - mae: 0.2538 - mse: 0.1329 - val_loss: 2.6680 - val_mae: 1.7532 - val_mse: 3.3061
# Epoch 21/40
# 116/116 [==============================] - 1s 7ms/step - loss: 1.1545 - mae: 0.2522 - mse: 0.1344 - val_loss: 2.4206 - val_mae: 1.5313 - val_mse: 2.5693
# Epoch 22/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.1288 - mae: 0.2538 - mse: 0.1343 - val_loss: 2.3560 - val_mae: 1.4924 - val_mse: 2.4479
# Epoch 23/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.0991 - mae: 0.2491 - mse: 0.1327 - val_loss: 2.2781 - val_mae: 1.4391 - val_mse: 2.2890
# Epoch 24/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.0730 - mae: 0.2469 - mse: 0.1326 - val_loss: 2.3203 - val_mae: 1.5048 - val_mse: 2.4797
# Epoch 25/40
# 116/116 [==============================] - 1s 6ms/step - loss: 1.0517 - mae: 0.2482 - mse: 0.1349 - val_loss: 2.5696 - val_mae: 1.7788 - val_mse: 3.3827
# Epoch 26/40
# 116/116 [==============================] - 1s 8ms/step - loss: 1.0317 - mae: 0.2490 - mse: 0.1358 - val_loss: 2.2622 - val_mae: 1.4888 - val_mse: 2.4258
# Epoch 27/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.0038 - mae: 0.2405 - mse: 0.1304 - val_loss: 2.1191 - val_mae: 1.3629 - val_mse: 2.0589
# Epoch 28/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.9836 - mae: 0.2379 - mse: 0.1289 - val_loss: 2.0524 - val_mae: 1.3146 - val_mse: 1.9265
# Epoch 29/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.9633 - mae: 0.2354 - mse: 0.1279 - val_loss: 2.3208 - val_mae: 1.6017 - val_mse: 2.7642
# Epoch 30/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.9447 - mae: 0.2329 - mse: 0.1262 - val_loss: 2.0537 - val_mae: 1.3493 - val_mse: 2.0124
# Epoch 31/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.9291 - mae: 0.2331 - mse: 0.1288 - val_loss: 1.9713 - val_mae: 1.2819 - val_mse: 1.8306
# Epoch 32/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.9085 - mae: 0.2276 - mse: 0.1260 - val_loss: 2.1576 - val_mae: 1.4849 - val_mse: 2.3930
# Epoch 33/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.8928 - mae: 0.2262 - mse: 0.1243 - val_loss: 2.1893 - val_mae: 1.5309 - val_mse: 2.5294
# Epoch 34/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.8785 - mae: 0.2252 - mse: 0.1264 - val_loss: 1.8424 - val_mae: 1.1945 - val_mse: 1.6015
# Epoch 35/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.8611 - mae: 0.2205 - mse: 0.1236 - val_loss: 2.0747 - val_mae: 1.4418 - val_mse: 2.2556
# Epoch 36/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.8556 - mae: 0.2278 - mse: 0.1272 - val_loss: 1.7289 - val_mae: 1.1062 - val_mse: 1.3926
# Epoch 37/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.8341 - mae: 0.2183 - mse: 0.1224 - val_loss: 1.9523 - val_mae: 1.3426 - val_mse: 1.9733
# Epoch 38/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.8211 - mae: 0.2159 - mse: 0.1216 - val_loss: 1.7983 - val_mae: 1.1977 - val_mse: 1.5978
# Epoch 39/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.8079 - mae: 0.2133 - mse: 0.1213 - val_loss: 1.9401 - val_mae: 1.3512 - val_mse: 1.9893
# Epoch 40/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.7982 - mae: 0.2138 - mse: 0.1221 - val_loss: 1.6180 - val_mae: 1.0375 - val_mse: 1.2323

# %%
# Plotting the history of Mean Absolute Error for training and validation sets
def plot_history(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Validation MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and validation loss curves

# %%
plot_history(LSTMhistory)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and validation

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_LSTM = LSTMmodel.predict(X_train_dense)
y_val_LSTM = LSTMmodel.predict(X_val_dense)

# Calculating the mean absolute error from the training and validation sets
mae_train_LSTM = mean_absolute_error(r_train_dense, y_train_LSTM)
mae_val_LSTM = mean_absolute_error(r_val_dense, y_val_LSTM)

# Printing the mean absolute error from the training and validation sets
print("\"Current Network throuput\n train mae = ", mae_train_LSTM,
      "\n validation mae = ", mae_val_LSTM)

# Printing the shapes of the predicted output from the training and validation sets
print(y_train_LSTM.shape)
print(y_val_LSTM.shape)
# Out:
# 116/116 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# "Current Network throuput
#  train mae =  0.22831818
#  validation mae =  1.0374749
# (3708, 1)
# (631, 1)

# %% [markdown]
# # Ploting out predictions on the validation set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions

scaled_predictions = scale_predictions_to_labels(r_val_dense[:700], y_val_LSTM[:700, 0])

# Now plotting the labels and predictions
plt.figure(figsize=(10, 5))
plt.plot(r_val_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Validation set)')  # Adding a title for context
plt.legend()
plt.show()

# %% [markdown]
# # Combining the training set and the validation set to create a larger training dataset.Trainining the model on this combined dataset to utilize all available data. Performing validation on the final test_set to assess the model's performance on unseen data.

# %%
# Creating our windowed data_set
X_train_all_dense,r_train_all_dense = create_dataset_windowed(train_all_scaled,train_all_labels)
X_test_dense,r_test_dense = create_dataset_windowed(test_scaled,test_labels)

print(X_train_all_dense.shape)
print(r_train_all_dense.shape)
print(X_test_dense.shape)
print(r_test_dense.shape)
# Out:
# (4546, 1, 2)
# (4546,)
# (633, 1, 2)
# (633,)

# %% [markdown]
# # Building and training our model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the LSTM to 256
HIDDEN_RNN = 256
# setting regularisers 
wreg = L1L2(l1=0.001, l2=0.01)

LSTM_model = Sequential()

# Adding layers to the model
LSTM_model.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTM_model.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTM_model.add(Dense(32,activation='relu'))
LSTM_model.add(Dense(16,activation='relu'))
LSTM_model.add(Dense(8,activation='relu'))
LSTM_model.add(Dense(1))
LSTM_model.summary()

LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTM_history = LSTM_model.fit(X_train_all_dense, r_train_all_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_dense, r_test_dense),
          shuffle=True)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_95 (Dense)            (None, 1, 64)             192
#
#  lstm_19 (LSTM)              (None, 256)               328704
#
#  dense_96 (Dense)            (None, 32)                8224
#
#  dense_97 (Dense)            (None, 16)                528
#
#  dense_98 (Dense)            (None, 8)                 136
#
#  dense_99 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 143/143 [==============================] - 5s 10ms/step - loss: 43.4441 - mae: 40.5053 - mse: 2119.7803 - val_loss: 90.0275 - val_mae: 87.7059 - val_mse: 7702.6826
# Epoch 2/40
# 143/143 [==============================] - 1s 7ms/step - loss: 40.6494 - mae: 38.7297 - mse: 1955.5721 - val_loss: 82.1778 - val_mae: 80.5572 - val_mse: 6498.6841
# Epoch 3/40
# 143/143 [==============================] - 1s 7ms/step - loss: 28.7097 - mae: 27.0864 - mse: 1070.6139 - val_loss: 41.6774 - val_mae: 39.8703 - val_mse: 1594.0442
# Epoch 4/40
# 143/143 [==============================] - 1s 7ms/step - loss: 9.3671 - mae: 7.4272 - mse: 84.5765 - val_loss: 14.6979 - val_mae: 12.7894 - val_mse: 165.2914
# Epoch 5/40
# 143/143 [==============================] - 1s 6ms/step - loss: 6.3741 - mae: 4.4949 - mse: 28.9447 - val_loss: 8.5719 - val_mae: 6.7048 - val_mse: 45.7324
# Epoch 6/40
# 143/143 [==============================] - 1s 6ms/step - loss: 4.3084 - mae: 2.4289 - mse: 10.0310 - val_loss: 3.7016 - val_mae: 1.7957 - val_mse: 3.4671
# Epoch 7/40
# 143/143 [==============================] - 1s 6ms/step - loss: 2.8096 - mae: 0.9066 - mse: 2.1291 - val_loss: 2.1602 - val_mae: 0.3037 - val_mse: 0.1913
# Epoch 8/40
# 143/143 [==============================] - 1s 6ms/step - loss: 2.4583 - mae: 0.6686 - mse: 1.1135 - val_loss: 2.3447 - val_mae: 0.6249 - val_mse: 0.5708
# Epoch 9/40
# 143/143 [==============================] - 1s 7ms/step - loss: 2.2275 - mae: 0.5626 - mse: 0.7580 - val_loss: 2.5922 - val_mae: 0.9904 - val_mse: 1.1832
# Epoch 10/40
# 143/143 [==============================] - 1s 9ms/step - loss: 2.0210 - mae: 0.4683 - mse: 0.5190 - val_loss: 2.3535 - val_mae: 0.8508 - val_mse: 0.9515
# Epoch 11/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.8542 - mae: 0.3981 - mse: 0.3546 - val_loss: 2.4164 - val_mae: 1.0023 - val_mse: 1.2577
# Epoch 12/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.7289 - mae: 0.3557 - mse: 0.2539 - val_loss: 2.7241 - val_mae: 1.3892 - val_mse: 2.2118
# Epoch 13/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.6253 - mae: 0.3264 - mse: 0.2021 - val_loss: 2.8168 - val_mae: 1.5527 - val_mse: 2.7216
# Epoch 14/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.5505 - mae: 0.3170 - mse: 0.1823 - val_loss: 3.2533 - val_mae: 2.0517 - val_mse: 4.5496
# Epoch 15/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.4867 - mae: 0.3096 - mse: 0.1716 - val_loss: 3.1393 - val_mae: 1.9893 - val_mse: 4.3041
# Epoch 16/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.4315 - mae: 0.3045 - mse: 0.1644 - val_loss: 2.9887 - val_mae: 1.8861 - val_mse: 3.9058
# Epoch 17/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.3815 - mae: 0.3008 - mse: 0.1611 - val_loss: 2.8918 - val_mae: 1.8320 - val_mse: 3.6994
# Epoch 18/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.3363 - mae: 0.2979 - mse: 0.1590 - val_loss: 2.7626 - val_mae: 1.7425 - val_mse: 3.3704
# Epoch 19/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.2953 - mae: 0.2961 - mse: 0.1576 - val_loss: 3.0719 - val_mae: 2.0939 - val_mse: 4.7331
# Epoch 20/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.2590 - mae: 0.2963 - mse: 0.1604 - val_loss: 2.6518 - val_mae: 1.7037 - val_mse: 3.2237
# Epoch 21/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.2164 - mae: 0.2867 - mse: 0.1513 - val_loss: 2.9508 - val_mae: 2.0397 - val_mse: 4.4953
# Epoch 22/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.1902 - mae: 0.2915 - mse: 0.1587 - val_loss: 2.6756 - val_mae: 1.7925 - val_mse: 3.5343
# Epoch 23/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.1527 - mae: 0.2832 - mse: 0.1523 - val_loss: 2.5830 - val_mae: 1.7264 - val_mse: 3.2912
# Epoch 24/40
# 143/143 [==============================] - 1s 10ms/step - loss: 1.1192 - mae: 0.2755 - mse: 0.1440 - val_loss: 2.6176 - val_mae: 1.7877 - val_mse: 3.5049
# Epoch 25/40
# 143/143 [==============================] - 1s 9ms/step - loss: 1.0966 - mae: 0.2777 - mse: 0.1507 - val_loss: 2.3981 - val_mae: 1.5902 - val_mse: 2.8205
# Epoch 26/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.0678 - mae: 0.2718 - mse: 0.1446 - val_loss: 2.5707 - val_mae: 1.7867 - val_mse: 3.4859
# Epoch 27/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.0384 - mae: 0.2642 - mse: 0.1389 - val_loss: 2.6974 - val_mae: 1.9361 - val_mse: 4.0441
# Epoch 28/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.0163 - mae: 0.2628 - mse: 0.1406 - val_loss: 2.3193 - val_mae: 1.5762 - val_mse: 2.7635
# Epoch 29/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9918 - mae: 0.2575 - mse: 0.1364 - val_loss: 2.0091 - val_mae: 1.2820 - val_mse: 1.9054
# Epoch 30/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9785 - mae: 0.2629 - mse: 0.1419 - val_loss: 2.2084 - val_mae: 1.5019 - val_mse: 2.5242
# Epoch 31/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9498 - mae: 0.2506 - mse: 0.1329 - val_loss: 2.2656 - val_mae: 1.5745 - val_mse: 2.7392
# Epoch 32/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9311 - mae: 0.2472 - mse: 0.1314 - val_loss: 2.3793 - val_mae: 1.7052 - val_mse: 3.1688
# Epoch 33/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.9115 - mae: 0.2427 - mse: 0.1314 - val_loss: 2.1453 - val_mae: 1.4846 - val_mse: 2.4536
# Epoch 34/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.8983 - mae: 0.2434 - mse: 0.1315 - val_loss: 2.0014 - val_mae: 1.3536 - val_mse: 2.0716
# Epoch 35/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.8861 - mae: 0.2455 - mse: 0.1341 - val_loss: 1.9364 - val_mae: 1.3024 - val_mse: 1.9341
# Epoch 36/40
# 143/143 [==============================] - 1s 8ms/step - loss: 0.8639 - mae: 0.2358 - mse: 0.1288 - val_loss: 1.5417 - val_mae: 0.9168 - val_mse: 1.0651
# Epoch 37/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.8529 - mae: 0.2365 - mse: 0.1288 - val_loss: 1.7050 - val_mae: 1.0936 - val_mse: 1.4208
# Epoch 38/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.8386 - mae: 0.2338 - mse: 0.1282 - val_loss: 1.8944 - val_mae: 1.2953 - val_mse: 1.9024
# Epoch 39/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.8241 - mae: 0.2297 - mse: 0.1262 - val_loss: 2.0971 - val_mae: 1.5095 - val_mse: 2.5036
# Epoch 40/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.8095 - mae: 0.2257 - mse: 0.1251 - val_loss: 1.6122 - val_mae: 1.0320 - val_mse: 1.2779

# %%
# Plotting the history of Mean Absolute Error for training_all_dataset and test sets
def plot_history_test(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train_all MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Test MAE')
  plt.legend()
  plt.show()

# %%
plot_history_test(LSTM_history)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and testing

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_all_LSTM = LSTM_model.predict(X_train_all_dense)
y_test_LSTM = LSTM_model.predict(X_test_dense)

# Calculating the mean absolute error from the training_all_dataset and test_set
mae_train_all_LSTM = mean_absolute_error(r_train_all_dense, y_train_all_LSTM)
mae_test_LSTM = mean_absolute_error(r_test_dense, y_test_LSTM)

# Printing the mean absolute error from the training_all_dataeet and test_set
print("\"Current Network throuput\" baseline:\n train mae = ", mae_train_all_LSTM,
      "\n validation mae = ", mae_test_LSTM)

# Checking the shapes of the predicted output from the training_all_dataset and test_set
print(y_train_all_LSTM.shape)
print(y_test_LSTM.shape)
# Out:
# 143/143 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# "Current Network throuput" baseline:
#  train mae =  0.22822951
#  validation mae =  1.0320448
# (4546, 1)
# (633, 1)

# %% [markdown]
# # Visualizing the predictions on the test set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions


scaled_predictions = scale_predictions_to_labels(r_test_dense[:700], y_test_LSTM[:700, 0])

# Now plotting the labels and scaled predictions
plt.figure(figsize=(10, 5))
plt.plot(r_test_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Test set)')
plt.legend()
plt.show()
