# %%
# Importing necessary libraries
import os
import math
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,GRU, Dropout, Lambda, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta, Nadam
from keras import regularizers, backend as K, utils
from keras.regularizers import Regularizer
from keras.utils import register_keras_serializable
from google.colab import drive
from datetime import datetime

# fixing random seed for reproducibility
seed = 2022
np.random.seed(seed)

# %%
# Mounting Google Drive to access files
drive.mount('/content/gdrive')
Increasing_BW_data = pd.read_fwf('/content/gdrive/My Drive/Data/Data_with_BW_Increasing/Increasing_BW.txt')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Steps below are performing some data_preprocessing

# %%
datasets = [Increasing_BW_data]

# %%
# Defining a function to apply the operation for removing strings from the data
def extract_and_convert_to_float(df):
    for column in df.columns:
      if pd.api.types.is_string_dtype(df[column]):
        df[column] = df[column].str.extract(r'(\d+[.\d]*)').astype(float)
    return df

for df in datasets:
    df = extract_and_convert_to_float(df)

# %%
# Dropping off irrelevant columns and only keeping the relevant
data_frames = [Increasing_BW_data]
for df in data_frames:
   df.drop(columns=df.columns.difference(['Transfer', 'Bandwidth']), inplace=True)

# %%
# introducing a new column into the data
df['increment'] = range(len(Increasing_BW_data))
# Dividing 'Transfer' column values by 1024 for data conversion to MBytes
Increasing_BW_data.loc[0:38, 'Transfer'] /= 1024

# %%
# Multiplying 'Bandwidth' column values by 1000 where the value is less than 5 to make uniformity of MBytes/Sec
Increasing_BW_data.loc[Increasing_BW_data['Bandwidth'] < 5, 'Bandwidth'] *= 1000
# Dropping off outlier points
Increasing_BW_data.drop([1159, 3980], inplace=True)

# %% [markdown]
# # Visualizing the data we shall make predictions on

# %%
import seaborn as sns
# Creating a plot to visualize the data
plt.figure(figsize=(12, 6))
sns.lineplot(x='increment', y='Transfer', data=Increasing_BW_data)
plt.xlabel('Time')
plt.ylabel('Transferred data(MBytes)')
plt.title('Variation of Transferred data with time')
plt.show()

# %%
# Checking the shape of the Data
Increasing_BW_data.shape
# Out:
# (5593, 3)

# %% [markdown]
# # Perfoming data splitting (Training_set, Validation_set, Test_set)

# %%
# Defining train_size as 70% of the length of the data & creating the train_set
train_size = int(0.7 * len(Increasing_BW_data))
train_set = Increasing_BW_data[:train_size]

# %%
# Defining validation_size as 15% of the length of the data and crating the val_set
val_size = int(0.15 * len(Increasing_BW_data))
val_set = Increasing_BW_data[train_size:train_size + val_size]

# %%
# Creating the test_set by selecting the data after the train_set and val_set
test_set = Increasing_BW_data[train_size + val_size:]

# %%
# Concatenating train_set and val_set to create train_all_data that will be used in testing
train_all = pd.concat([train_set, val_set], axis=0)

# %%
# Extracting data from dataframes, selecting the features
# The labels simply contain the Transferred Trafic

#  Selecting which features to use:

def feature_matrix(df,features):
    numsamples = df.shape[0]
    numfeatures = len(features)

    fm = np.zeros((numsamples,numfeatures))
    for idx in range(numfeatures):
        fm[:,idx] = df[features[idx]]
    return fm

features = ['Bandwidth', 'Transfer']

# Important: Tensorflow 2.x gives an error omitting
# the np.asarray(...,,dtype=np.float32)

# trainining  and validation data
train_values = np.asarray(feature_matrix(train_set,features),dtype=np.float32)
train_labels = np.asarray(train_set['Transfer'],dtype=np.float32)

val_values = np.asarray(feature_matrix(val_set,features),dtype=np.float32)
val_labels = np.asarray(val_set['Transfer'],dtype=np.float32)

# train_all_data for retraining before testing
train_all_values = np.asarray(feature_matrix(train_all,features),dtype=np.float32)
train_all_labels = np.asarray(train_all['Transfer'],dtype=np.float32)

# test data
test_values = np.asarray(feature_matrix(test_set,features),dtype=np.float32)
test_labels = np.asarray(test_set['Transfer'],dtype=np.float32)



# checking the data
print(train_values.shape)
print(train_labels.shape)

print(val_values.shape)
print(val_labels.shape)

print(train_all_values.shape)
print(train_all_labels.shape)

print(test_values.shape)
print(test_labels.shape)
# Out:
# (3915, 2)
# (3915,)
# (838, 2)
# (838,)
# (4753, 2)
# (4753,)
# (840, 2)
# (840,)

# %%
# Creating a MinMaxScaler instance SS1 and fitting it to train_values
SS1 = MinMaxScaler()
SS1.fit(train_values)

# Transforming train_values and val_values using SS1
train_scaled = SS1.transform(train_values)
val_scaled = SS1.transform(val_values)

# Creating another MinMaxScaler instance SS2 and fitting it to train_all_values
SS2 = MinMaxScaler()
SS2.fit(train_all_values)

# Transforming train_all_values and test_values using SS2
train_all_scaled = SS2.transform(train_all_values)
test_scaled = SS2.transform(test_values)

# %% [markdown]
# # Setting the Window_size

# %%
WINDOW_SIZE = 10

# %%
# Function to create windowed dataset for time series forecasting 4 seconds in the future
def create_dataset_windowed(features, labels, ahead=8, window_size=WINDOW_SIZE, max_window_size=200):
    samples = features.shape[0]-ahead-(max_window_size-1)
    window_size = min(max(window_size,1),max_window_size)

    dataX = []
    for i in range(samples):
        a = features[(i+max_window_size-window_size):(i+max_window_size), :]
        dataX.append(a)
    return np.array(dataX), labels[ahead+max_window_size-1:]

# %% [markdown]
# # Creating the windowed data_set for training and validation

# %%
# Creating windowed datasets for training and validation sets
X_train_dense, r_train_dense = create_dataset_windowed(train_scaled, train_labels)
X_val_dense, r_val_dense = create_dataset_windowed(val_scaled, val_labels)

# Printing shapes of the created datasets
print(X_train_dense.shape)
print(r_train_dense.shape)
print(X_val_dense.shape)
print(r_val_dense.shape)
# Out:
# (3708, 10, 2)
# (3708,)
# (631, 10, 2)
# (631,)

# %% [markdown]
# # Building the training model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the LSTM to 256
HIDDEN_RNN = 256
# setting regularisers
wreg = L1L2(l1=0.001, l2=0.01)

LSTMmodel = Sequential()

# Adding layers to the model
LSTMmodel.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTMmodel.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTMmodel.add(Dense(32,activation='relu'))
LSTMmodel.add(Dense(16,activation='relu'))
LSTMmodel.add(Dense(8,activation='relu'))
LSTMmodel.add(Dense(1))
LSTMmodel.summary()

LSTMmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTMhistory = LSTMmodel.fit(X_train_dense, r_train_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_dense, r_val_dense),
          shuffle=True)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_110 (Dense)           (None, 10, 64)            192
#
#  lstm_22 (LSTM)              (None, 256)               328704
#
#  dense_111 (Dense)           (None, 32)                8224
#
#  dense_112 (Dense)           (None, 16)                528
#
#  dense_113 (Dense)           (None, 8)                 136
#
#  dense_114 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 116/116 [==============================] - 4s 11ms/step - loss: 33.4860 - mae: 30.3976 - mse: 1235.2908 - val_loss: 65.3586 - val_mae: 62.7472 - val_mse: 3946.5374
# Epoch 2/40
# 116/116 [==============================] - 1s 7ms/step - loss: 21.9208 - mae: 19.7285 - mse: 630.0275 - val_loss: 53.8491 - val_mae: 52.0396 - val_mse: 2717.4438
# Epoch 3/40
# 116/116 [==============================] - 1s 7ms/step - loss: 13.1883 - mae: 11.6840 - mse: 285.2944 - val_loss: 40.9027 - val_mae: 39.6735 - val_mse: 1583.2192
# Epoch 4/40
# 116/116 [==============================] - 1s 8ms/step - loss: 7.0398 - mae: 6.0149 - mse: 92.4287 - val_loss: 28.5967 - val_mae: 27.7527 - val_mse: 779.1744
# Epoch 5/40
# 116/116 [==============================] - 1s 11ms/step - loss: 3.5149 - mae: 2.8026 - mse: 22.0336 - val_loss: 19.5305 - val_mae: 18.9313 - val_mse: 366.4823
# Epoch 6/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.8800 - mae: 1.3587 - mse: 4.9377 - val_loss: 13.6539 - val_mae: 13.1986 - val_mse: 181.3580
# Epoch 7/40
# 116/116 [==============================] - 1s 10ms/step - loss: 1.1430 - mae: 0.7299 - mse: 1.2586 - val_loss: 10.3962 - val_mae: 10.0171 - val_mse: 106.5775
# Epoch 8/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.9170 - mae: 0.5554 - mse: 0.5588 - val_loss: 8.6165 - val_mae: 8.2666 - val_mse: 74.1760
# Epoch 9/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.8162 - mae: 0.4728 - mse: 0.3733 - val_loss: 7.8349 - val_mae: 7.4973 - val_mse: 61.5566
# Epoch 10/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7581 - mae: 0.4254 - mse: 0.3048 - val_loss: 7.1446 - val_mae: 6.8165 - val_mse: 51.6561
# Epoch 11/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7689 - mae: 0.4444 - mse: 0.3246 - val_loss: 6.6265 - val_mae: 6.3055 - val_mse: 44.7837
# Epoch 12/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6957 - mae: 0.3779 - mse: 0.2326 - val_loss: 6.5102 - val_mae: 6.1955 - val_mse: 42.9716
# Epoch 13/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7143 - mae: 0.4021 - mse: 0.2599 - val_loss: 6.2089 - val_mae: 5.8994 - val_mse: 39.3483
# Epoch 14/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6848 - mae: 0.3776 - mse: 0.2313 - val_loss: 5.8548 - val_mae: 5.5497 - val_mse: 35.3157
# Epoch 15/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6890 - mae: 0.3860 - mse: 0.2386 - val_loss: 5.6935 - val_mae: 5.3925 - val_mse: 33.4829
# Epoch 16/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.7291 - mae: 0.4297 - mse: 0.3258 - val_loss: 5.7107 - val_mae: 5.4134 - val_mse: 33.4448
# Epoch 17/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6366 - mae: 0.3409 - mse: 0.1888 - val_loss: 5.4134 - val_mae: 5.1192 - val_mse: 30.4223
# Epoch 18/40
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6665 - mae: 0.3739 - mse: 0.2358 - val_loss: 5.3761 - val_mae: 5.0853 - val_mse: 29.8319
# Epoch 19/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6276 - mae: 0.3381 - mse: 0.1863 - val_loss: 5.2249 - val_mae: 4.9370 - val_mse: 28.3152
# Epoch 20/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.6650 - mae: 0.3782 - mse: 0.2400 - val_loss: 4.8559 - val_mae: 4.5700 - val_mse: 25.1874
# Epoch 21/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.6473 - mae: 0.3632 - mse: 0.2131 - val_loss: 5.2480 - val_mae: 4.9653 - val_mse: 28.4476
# Epoch 22/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.6609 - mae: 0.3793 - mse: 0.2386 - val_loss: 5.0600 - val_mae: 4.7797 - val_mse: 26.6363
# Epoch 23/40
# 116/116 [==============================] - 1s 8ms/step - loss: 0.6409 - mae: 0.3617 - mse: 0.2120 - val_loss: 5.0199 - val_mae: 4.7417 - val_mse: 26.2222
# Epoch 24/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6307 - mae: 0.3537 - mse: 0.2104 - val_loss: 4.8730 - val_mae: 4.5971 - val_mse: 24.8979
# Epoch 25/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6232 - mae: 0.3483 - mse: 0.2014 - val_loss: 4.9459 - val_mae: 4.6720 - val_mse: 25.4511
# Epoch 26/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6624 - mae: 0.3895 - mse: 0.2554 - val_loss: 4.9631 - val_mae: 4.6913 - val_mse: 25.6211
# Epoch 27/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6073 - mae: 0.3364 - mse: 0.1845 - val_loss: 5.0136 - val_mae: 4.7438 - val_mse: 25.9524
# Epoch 28/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5712 - mae: 0.3023 - mse: 0.1497 - val_loss: 4.6926 - val_mae: 4.4248 - val_mse: 23.1902
# Epoch 29/40
# 116/116 [==============================] - 1s 8ms/step - loss: 0.6492 - mae: 0.3821 - mse: 0.2415 - val_loss: 4.5280 - val_mae: 4.2617 - val_mse: 21.9622
# Epoch 30/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6499 - mae: 0.3846 - mse: 0.2449 - val_loss: 4.4776 - val_mae: 4.2128 - val_mse: 21.5403
# Epoch 31/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5771 - mae: 0.3136 - mse: 0.1575 - val_loss: 4.9095 - val_mae: 4.6468 - val_mse: 24.9873
# Epoch 32/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.6553 - mae: 0.3933 - mse: 0.2552 - val_loss: 4.8489 - val_mae: 4.5879 - val_mse: 24.4540
# Epoch 33/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5804 - mae: 0.3201 - mse: 0.1648 - val_loss: 4.4445 - val_mae: 4.1851 - val_mse: 21.1540
# Epoch 34/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5616 - mae: 0.3030 - mse: 0.1492 - val_loss: 4.4312 - val_mae: 4.1733 - val_mse: 21.0090
# Epoch 35/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.6127 - mae: 0.3556 - mse: 0.2145 - val_loss: 4.1532 - val_mae: 3.8967 - val_mse: 19.0070
# Epoch 36/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.6412 - mae: 0.3855 - mse: 0.2361 - val_loss: 4.5530 - val_mae: 4.2981 - val_mse: 22.0143
# Epoch 37/40
# 116/116 [==============================] - 1s 10ms/step - loss: 0.5847 - mae: 0.3306 - mse: 0.1801 - val_loss: 4.5886 - val_mae: 4.3353 - val_mse: 22.2240
# Epoch 38/40
# 116/116 [==============================] - 1s 9ms/step - loss: 0.5835 - mae: 0.3308 - mse: 0.1818 - val_loss: 4.3460 - val_mae: 4.0940 - val_mse: 20.3396
# Epoch 39/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5777 - mae: 0.3265 - mse: 0.1724 - val_loss: 4.5110 - val_mae: 4.2605 - val_mse: 21.5086
# Epoch 40/40
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5584 - mae: 0.3086 - mse: 0.1583 - val_loss: 4.1763 - val_mae: 3.9272 - val_mse: 18.9864

# %%
# Plotting the history of Mean Absolute Error for training and validation sets
def plot_history(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Validation MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and validation loss curves

# %%
plot_history(LSTMhistory)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and validation

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_LSTM = LSTMmodel.predict(X_train_dense)
y_val_LSTM = LSTMmodel.predict(X_val_dense)

# Calculating the mean absolute error from the training and validation set
mae_train_LSTM = mean_absolute_error(r_train_dense, y_train_LSTM)
mae_val_LSTM = mean_absolute_error(r_val_dense, y_val_LSTM)

# Printing the mean absolute error from the training and validation set
print("\"Current Network throuput\n train mae = ", mae_train_LSTM,
      "\n validation mae = ", mae_val_LSTM)

# Printing the shapes of the predicted output from the training and validation set
print(y_train_LSTM.shape)
print(y_val_LSTM.shape)
# Out:
# 116/116 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# "Current Network throuput
#  train mae =  0.49772307
#  validation mae =  3.9271579
# (3708, 1)
# (631, 1)

# %% [markdown]
# # Ploting out predictions on the validation set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions

scaled_predictions = scale_predictions_to_labels(r_val_dense[:700], y_val_LSTM[:700, 0])

# Now plotting the labels and predictions
plt.figure(figsize=(10, 5))
plt.plot(r_val_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Validation set)')  # Adding a title for context
plt.legend()
plt.show()

# %% [markdown]
# # Combining the training set and the validation set to create a larger training dataset.Trainining the model on this combined dataset to utilize all available data. Performing validation on the final test_set to assess the model's performance on unseen data.

# %%
# Creating the windowed data_set
X_train_all_dense,r_train_all_dense = create_dataset_windowed(train_all_scaled,train_all_labels)
X_test_dense,r_test_dense = create_dataset_windowed(test_scaled,test_labels)

print(X_train_all_dense.shape)
print(r_train_all_dense.shape)
print(X_test_dense.shape)
print(r_test_dense.shape)
# Out:
# (4546, 10, 2)
# (4546,)
# (633, 10, 2)
# (633,)

# %% [markdown]
# # Building and training the model

# %%
from tensorflow.keras.regularizers import L1L2
# Setting the number of units for the hidden layer in the RNN to 256
HIDDEN_RNN = 256
# setting regularisers
wreg = L1L2(l1=0.001, l2=0.01)

LSTM_model = Sequential()

# Adding layers to the model
LSTM_model.add(Dense(64, input_shape=(WINDOW_SIZE,2), activation='relu'))
LSTM_model.add(LSTM(input_shape = (WINDOW_SIZE,2),
                   units=HIDDEN_RNN,
                   return_sequences=False,
                   kernel_regularizer=wreg))

LSTM_model.add(Dense(32,activation='relu'))
LSTM_model.add(Dense(16,activation='relu'))
LSTM_model.add(Dense(8,activation='relu'))
LSTM_model.add(Dense(1))
LSTM_model.summary()

LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss='mae', metrics=['mae','mse'])

batch_size=32
epochs=40

# Training the model
LSTM_history = LSTM_model.fit(X_train_all_dense, r_train_all_dense,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_dense, r_test_dense),
          shuffle=True)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_115 (Dense)           (None, 10, 64)            192
#
#  lstm_23 (LSTM)              (None, 256)               328704
#
#  dense_116 (Dense)           (None, 32)                8224
#
#  dense_117 (Dense)           (None, 16)                528
#
#  dense_118 (Dense)           (None, 8)                 136
#
#  dense_119 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 337793 (1.29 MB)
# Trainable params: 337793 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 143/143 [==============================] - 6s 15ms/step - loss: 37.1431 - mae: 34.1458 - mse: 1630.6716 - val_loss: 70.9170 - val_mae: 68.4943 - val_mse: 4701.9507
# Epoch 2/40
# 143/143 [==============================] - 1s 7ms/step - loss: 17.9488 - mae: 15.9854 - mse: 509.2885 - val_loss: 47.9864 - val_mae: 46.4388 - val_mse: 2166.9570
# Epoch 3/40
# 143/143 [==============================] - 1s 7ms/step - loss: 7.2831 - mae: 6.0305 - mse: 102.9279 - val_loss: 27.6736 - val_mae: 26.6732 - val_mse: 721.0810
# Epoch 4/40
# 143/143 [==============================] - 1s 7ms/step - loss: 2.5960 - mae: 1.7642 - mse: 10.7226 - val_loss: 15.2618 - val_mae: 14.5730 - val_mse: 220.9837
# Epoch 5/40
# 143/143 [==============================] - 1s 7ms/step - loss: 1.2953 - mae: 0.7016 - mse: 1.1652 - val_loss: 10.2678 - val_mae: 9.7536 - val_mse: 102.1358
# Epoch 6/40
# 143/143 [==============================] - 1s 6ms/step - loss: 1.1221 - mae: 0.6546 - mse: 0.7282 - val_loss: 8.7849 - val_mae: 8.3516 - val_mse: 76.0810
# Epoch 7/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.9531 - mae: 0.5336 - mse: 0.4881 - val_loss: 7.5345 - val_mae: 7.1254 - val_mse: 56.7275
# Epoch 8/40
# 143/143 [==============================] - 1s 6ms/step - loss: 0.8561 - mae: 0.4551 - mse: 0.3577 - val_loss: 7.1327 - val_mae: 6.7393 - val_mse: 50.7666
# Epoch 9/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.8215 - mae: 0.4345 - mse: 0.3148 - val_loss: 6.5085 - val_mae: 6.1278 - val_mse: 42.7430
# Epoch 10/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.8071 - mae: 0.4319 - mse: 0.3184 - val_loss: 6.2154 - val_mae: 5.8455 - val_mse: 39.0800
# Epoch 11/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.7583 - mae: 0.3932 - mse: 0.2507 - val_loss: 5.9224 - val_mae: 5.5621 - val_mse: 35.6499
# Epoch 12/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.7285 - mae: 0.3723 - mse: 0.2299 - val_loss: 5.3828 - val_mae: 5.0307 - val_mse: 30.1672
# Epoch 13/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.7723 - mae: 0.4241 - mse: 0.2963 - val_loss: 5.5167 - val_mae: 5.1723 - val_mse: 31.3780
# Epoch 14/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.7698 - mae: 0.4288 - mse: 0.3033 - val_loss: 5.5812 - val_mae: 5.2436 - val_mse: 31.9272
# Epoch 15/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6706 - mae: 0.3362 - mse: 0.1857 - val_loss: 5.3414 - val_mae: 5.0101 - val_mse: 29.4538
# Epoch 16/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6813 - mae: 0.3530 - mse: 0.2014 - val_loss: 4.9217 - val_mae: 4.5963 - val_mse: 25.7301
# Epoch 17/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.7082 - mae: 0.3857 - mse: 0.2416 - val_loss: 5.2920 - val_mae: 4.9724 - val_mse: 28.9492
# Epoch 18/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6520 - mae: 0.3349 - mse: 0.1867 - val_loss: 5.5433 - val_mae: 5.2289 - val_mse: 31.2079
# Epoch 19/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.7824 - mae: 0.4703 - mse: 0.3823 - val_loss: 5.7543 - val_mae: 5.4446 - val_mse: 33.3715
# Epoch 20/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6711 - mae: 0.3637 - mse: 0.2199 - val_loss: 5.3833 - val_mae: 5.0783 - val_mse: 29.6989
# Epoch 21/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6894 - mae: 0.3866 - mse: 0.2435 - val_loss: 5.2194 - val_mae: 4.9187 - val_mse: 28.2686
# Epoch 22/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6761 - mae: 0.3774 - mse: 0.2316 - val_loss: 5.4537 - val_mae: 5.1571 - val_mse: 30.4790
# Epoch 23/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6554 - mae: 0.3607 - mse: 0.2130 - val_loss: 5.3258 - val_mae: 5.0328 - val_mse: 29.1966
# Epoch 24/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6592 - mae: 0.3682 - mse: 0.2234 - val_loss: 5.2723 - val_mae: 4.9833 - val_mse: 28.7329
# Epoch 25/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.6243 - mae: 0.3370 - mse: 0.1862 - val_loss: 4.8336 - val_mae: 4.5480 - val_mse: 24.8093
# Epoch 26/40
# 143/143 [==============================] - 1s 10ms/step - loss: 0.6544 - mae: 0.3707 - mse: 0.2350 - val_loss: 5.4028 - val_mae: 5.1208 - val_mse: 29.9003
# Epoch 27/40
# 143/143 [==============================] - 1s 9ms/step - loss: 0.6620 - mae: 0.3816 - mse: 0.2371 - val_loss: 5.1490 - val_mae: 4.8704 - val_mse: 27.5408
# Epoch 28/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6301 - mae: 0.3530 - mse: 0.2098 - val_loss: 4.9870 - val_mae: 4.7116 - val_mse: 26.1033
# Epoch 29/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6235 - mae: 0.3495 - mse: 0.1957 - val_loss: 4.9012 - val_mae: 4.6287 - val_mse: 25.2901
# Epoch 30/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6058 - mae: 0.3348 - mse: 0.1785 - val_loss: 5.1592 - val_mae: 4.8897 - val_mse: 27.4409
# Epoch 31/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6124 - mae: 0.3442 - mse: 0.1937 - val_loss: 4.3255 - val_mae: 4.0585 - val_mse: 20.6475
# Epoch 32/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6495 - mae: 0.3841 - mse: 0.2448 - val_loss: 5.0485 - val_mae: 4.7846 - val_mse: 26.5194
# Epoch 33/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5898 - mae: 0.3272 - mse: 0.1746 - val_loss: 4.8797 - val_mae: 4.6185 - val_mse: 24.9982
# Epoch 34/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6634 - mae: 0.4033 - mse: 0.2749 - val_loss: 4.7971 - val_mae: 4.5382 - val_mse: 24.4749
# Epoch 35/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5806 - mae: 0.3231 - mse: 0.1685 - val_loss: 4.3002 - val_mae: 4.0437 - val_mse: 20.4579
# Epoch 36/40
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6622 - mae: 0.4071 - mse: 0.2838 - val_loss: 4.5131 - val_mae: 4.2591 - val_mse: 22.1127
# Epoch 37/40
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5855 - mae: 0.3327 - mse: 0.1822 - val_loss: 4.2849 - val_mae: 4.0331 - val_mse: 20.3713
# Epoch 38/40
# 143/143 [==============================] - 1s 10ms/step - loss: 0.5774 - mae: 0.3270 - mse: 0.1748 - val_loss: 4.5687 - val_mae: 4.3194 - val_mse: 22.3976
# Epoch 39/40
# 143/143 [==============================] - 1s 10ms/step - loss: 0.5757 - mae: 0.3275 - mse: 0.1761 - val_loss: 5.2481 - val_mae: 5.0010 - val_mse: 28.1441
# Epoch 40/40
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5993 - mae: 0.3533 - mse: 0.2056 - val_loss: 4.3048 - val_mae: 4.0599 - val_mse: 20.3860

# %%
# Plotting the history of Mean Absolute Error for training_all_dataset and test sets
def plot_history_test(history):
  plt.figure(figsize = (6,4))

  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.plot(history.epoch, np.array(history.history['mae']),'g-',
           label='Train_all MAE')
  plt.plot(history.epoch, np.array(history.history['val_mae']),'r-',
           label = 'Test MAE')
  plt.legend()
  plt.show()

# %% [markdown]
# # Plotting the training and test loss curves

# %%
plot_history_test(LSTM_history)

# %% [markdown]
# # Calculating the average Mean Absolute Error from training and testing

# %%
from sklearn.metrics import mean_absolute_error
# Making predictions using the trained model
y_train_all_LSTM = LSTM_model.predict(X_train_all_dense)
y_test_LSTM = LSTM_model.predict(X_test_dense)

# Calculating the mean absolute error from the training_all_dataset and test_set
mae_train_all_LSTM = mean_absolute_error(r_train_all_dense, y_train_all_LSTM)
mae_test_LSTM = mean_absolute_error(r_test_dense, y_test_LSTM)

# Printing the mean absolute error from the training_all_dataeet and test_set
print("\"Current Network throuput\" baseline:\n train mae = ", mae_train_all_LSTM,
      "\n validation mae = ", mae_test_LSTM)

# Checking the shapes of the predicted output from the training_all_dataset and test_set
print(y_train_all_LSTM.shape)
print(y_test_LSTM.shape)
# Out:
# 143/143 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# "Current Network throuput" baseline:
#  train mae =  0.53662837
#  validation mae =  4.0598874
# (4546, 1)
# (633, 1)

# %% [markdown]
# # Visualizing the predictions on the test set

# %%
def scale_predictions_to_labels(labels, predictions):

    scaled_predictions = predictions
    return scaled_predictions


scaled_predictions = scale_predictions_to_labels(r_test_dense[:700], y_test_LSTM[:700, 0])

# Now plotting the labels and scaled predictions
plt.figure(figsize=(10, 5))
plt.plot(r_test_dense[:700], 'k-', label='Actual data transferred')
plt.plot(scaled_predictions[:700], 'r-', label='Predicted data transferred 4 seconds ahead')
plt.ylabel('Network data transferred (MBytes)')
plt.xlabel('First 700 transmissions')
plt.title('Comparison of Actual vs. Predicted transferred data over 700 Transmissions (Test set)')
plt.legend()
plt.show()
